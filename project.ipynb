# %%
from ngsolve import *
from netgen.occ import *
from ngsolve.webgui import Draw

# %% [markdown]
# ## Numerics

# %% [markdown]
# ### Exercise 8.

# %% [markdown]
# We want to solve the PDE-constrained shape optimization problem
#
# $$
# \min_{\Omega \subset \mathsf{D}} J(u)
# := \int_\Omega |u_\Omega - u_{ref}|^2 \, dx
# $$
#
# subject to $(\Omega,u_\Omega)$ satisfying
#
# $$
# \int_\Omega \nabla u_\Omega \cdot \nabla v + u_\Omega v \, dx
# =
# \int_\Omega f v \, dx
# \quad \text{for all } v \in H_0^1(\Omega),
# $$
#
# where $\Omega \subset \mathbb{R}^2$ and
# $u_d, f \in C^1(\mathbb{R}^2)$.

# %%
geo = unit_square.GenerateMesh(maxh=0.1)
mesh = Mesh(geo)
#Draw(mesh)

f = CoefficientFunction(1)
ud = exp(-4**2*((y-0.5)**2+ (x-0.5)**2))

grad_f = CoefficientFunction( (f.Diff(x), f.Diff(y) ) )
grad_ud = CoefficientFunction( (ud.Diff(x), ud.Diff(y) ) )

# %%
fes = H1(mesh, order=2, dirichlet=".*")
u, v = fes.TnT()
gfu = GridFunction(fes)
scene = Draw (gfu, mesh, "state")

a = BilinearForm(fes, symmetric=True)
a += grad(u)*grad(v)*dx
a += u*v*dx

fstate = LinearForm(fes)
fstate += f*v*dx
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
def SolveStateEquation():
    rhs = gfu.vec.CreateVector()
    rhs.data = fstate.vec - a.mat * gfu.vec
    update = gfu.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()) * rhs
    gfu.vec.data += update

# %%
a.Assemble()
fstate.Assemble()
SolveStateEquation()
scene.Redraw()

# %% [markdown]
# ### Adjoint equation
#
# The adjoint p satisfies
#
# $$
# \int_\Omega \nabla w \cdot \nabla p + w p \, dx
# =
# -2 \int_\Omega (u_\Omega - u_{ref}) w
# \quad \text{for all } w \in H_0^1(\Omega),
# $$

# %%
def Cost(u):
    return (u - ud)**2 * dx

p, w = fes.TnT()
gfp = GridFunction(fes)
scene = Draw (gfp, mesh, "adjoint")

fadjoint = LinearForm(fes)
#fadjoint += -1*Cost(gfu).Diff(gfu,w)
fadjoint += -2*(gfu - ud)*w*dx
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
def SolveAdjointEquation():
    # can use A since diff op is self adjoint
    rhs = gfp.vec.CreateVector()
    rhs.data = fadjoint.vec - a.mat.T * gfp.vec
    update = gfp.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()).T * rhs
    gfp.vec.data += update

# %%
fadjoint.Assemble()
SolveAdjointEquation()
scene.Redraw()

# %% [markdown]
# The shape derivative of the shape function
#
# $$
# \mathcal{J}(\Omega) := \int_\Omega |u - u_d|^2 \, dx
# $$
#
# at $\Omega$ in direction $X$ is given by
#
# $$
# \begin{aligned}
# d\mathcal{J}(\Omega; X)
# =& \int_{\Omega} \operatorname{div}(X)\, |u - u_d|^2
# - 2 (u - u_d)\, \nabla u_d \cdot X \, dx \\
# &+ \int_{\Omega}
# \bigl( \operatorname{div}(X) I - D X - D X^\top \bigr)
# \nabla u \cdot \nabla p \, dx \\
# &+ \int_\Omega \operatorname{div}(X) u p \, dx \\
# &- \int_{\Omega}
# \bigl( \nabla f \cdot X + f \operatorname{div}(X) \bigr) p \, dx .
# \end{aligned}
# $$
#
# We now assemble this shape derivative in NGSolve as follows:

# %%
VEC = H1(mesh, order=2, dim=2)
PHI, X = VEC.TnT()

dJOmega = LinearForm(VEC)
dJOmega += SymbolicLFI(div(X)*((gfu - ud)**2) - 2*grad_ud*X*(gfu - ud))
dJOmega += SymbolicLFI((div(X)*InnerProduct(grad(gfu),grad(gfp))))
dJOmega += SymbolicLFI((-InnerProduct(X.Deriv()*grad(gfu), grad(gfp))))
dJOmega += SymbolicLFI((-InnerProduct(grad(gfu),X.Deriv()*grad(gfp))))      # Transpose by shifting in scalar product
dJOmega += SymbolicLFI(div(X)*gfu*gfp)
dJOmega += SymbolicLFI(-InnerProduct(grad_f,X)*gfp)
dJOmega += SymbolicLFI(-f*div(X)*gfp)

# %% [markdown]
# - Next, we want to find a vector field $X$ which yields a decrease of the objective
#   function, i.e. we want to find a vector field $X$ such that
#
#   $$
#   d\mathcal{J}(\Omega; X) < 0.
#   $$
#
# - This can be achieved by solving an auxiliary boundary value problem of the type
#
#   $$
#   \text{Find } X \in H :
#   \qquad
#   b(X, \Phi) = d\mathcal{J}(\Omega; \Phi)
#   \quad \text{for all } \Phi \in H,
#   $$
#
#   for a suitable Hilbert space $H$ (e.g. $H = H^1(\Omega)^2$).
#   Here, $b(\cdot,\cdot) : H \times H \to \mathbb{R}$ is a positive definite bilinear
#   form which we are free to choose. Then $-X$ is a descent direction since
#
#   $$
#   d\mathcal{J}(\Omega; -X)
#   = - d\mathcal{J}(\Omega; X)
#   = - b(X, X)
#   < 0.
#   $$
#
# - For now, we start with the bilinear form
#
#   $$
#   b(X, Y)
#   =
#   \int_\Omega \nabla X : \nabla Y + X \cdot Y \, dx .
#   $$

# %%
def pose_deformation_equation(gamma=None): 
    # Bilinearform of Exercise 8/9
    b = BilinearForm(VEC)
    b += InnerProduct(grad(X),grad(PHI))*dx + InnerProduct(X,PHI)*dx
    if gamma:
        print('Using gamma =', gamma)
        b += gamma * InnerProduct(CF((-X.Diff(x)+X.Diff(y), X.Diff(x)+X.Diff(y))), CF((-PHI.Diff(x)+PHI.Diff(y), PHI.Diff(x)+PHI.Diff(y)))) * dx
    #print("Expression tree \n", b)
    return b

def SolveDeformationEquation():
    rhs = gfX.vec.CreateVector()
    rhs.data = dJOmega.vec - b.mat * gfX.vec
    update = gfX.vec.CreateVector()
    update.data = b.mat.Inverse(VEC.FreeDofs()) * rhs
    gfX.vec.data += update

# %%
def optimize_shape():
    gfset.Set((0,0))
    mesh.SetDeformation(gfset)
    scene.Redraw()
    a.Assemble()
    fstate.Assemble()
    SolveStateEquation()

    LineSearch = True

    iter_max = 600
    Jold = Integrate(Cost(gfu), mesh)
    converged = False

    # input("Press enter to start optimization")
    print('Cost at initial design', Integrate (Cost(gfu), mesh))
    for k in range(iter_max):
        mesh.SetDeformation(gfset)
        scene.Redraw()

        print('cost at iteration', k, ': ', Jold)

        a.Assemble()
        fstate.Assemble()
        SolveStateEquation()

        fadjoint.Assemble()
        SolveAdjointEquation()

        b.Assemble()
        dJOmega.Assemble()
        SolveDeformationEquation()

        scale = 0.01 / Norm(gfX.vec)
        gfsetOld = gfset
        gfset.vec.data -= scale * gfX.vec

        Jnew = Integrate(Cost(gfu), mesh)

        if LineSearch:
            while Jnew > Jold and scale > 1e-12:
                #input('a')
                scale = scale / 2
                print("scale = ", scale)
                #print("scale without normalization factor = ", scale* Norm(gfX.vec))
                if scale <= 1e-12:
                    converged = True
                    break

                gfset.vec.data = gfsetOld.vec - scale * gfX.vec         # scale times -X is descent direction
                mesh.SetDeformation(gfset)                              # applying deformation and solve new state

                a.Assemble()                                           # note that during line search we only have to solve state to check if update yields lower costs              
                fstate.Assemble()
                SolveStateEquation()
                Jnew = Integrate(Cost(gfu), mesh)
                print("New cost during line search: ", Jnew)

        if converged==True:
            print("No more descent can be found")
            break
        Jold = Jnew

        Redraw(blocking=True)

    print("Norm of gset", Integrate(gfset**2, mesh))

# %%
b = pose_deformation_equation(gamma= 3)
gfX = GridFunction(VEC)

# gfset denotes the deformation of the original domain and will be updated during the shape optimization
gfset = GridFunction(VEC)
gfset.Set((0,0))
scene = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)

optimize_shape()
# Out:
# Using gamma = 3
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# Cost at initial design 0.07797736156507301
# cost at iteration 0 :  0.07797736156507301
# cost at iteration 1 :  0.07796153130230203
# cost at iteration 2 :  0.07786485030893471
# cost at iteration 3 :  0.07776817189590422
# cost at iteration 4 :  0.07767149889477505
# cost at iteration 5 :  0.07757483411583313
# cost at iteration 6 :  0.0774781803488548
# cost at iteration 7 :  0.0773815403638579
# cost at iteration 8 :  0.07728491691183546
# cost at iteration 9 :  0.07718831272547264
# cost at iteration 10 :  0.07709173051984639
# cost at iteration 11 :  0.07699517299310918
# cost at iteration 12 :  0.07689864282715651
# cost at iteration 13 :  0.07680214268827837
# cost at iteration 14 :  0.07670567522779552
# cost at iteration 7 :  0.0773815403638579
# cost at iteration 8 :  0.07728491691183546
# cost at iteration 9 :  0.07718831272547264
# cost at iteration 10 :  0.07709173051984639
# cost at iteration 11 :  0.07699517299310918
# cost at iteration 12 :  0.07689864282715651
# cost at iteration 13 :  0.07680214268827837
# cost at iteration 14 :  0.07670567522779552
# cost at iteration 15 :  0.07660924308268023
# cost at iteration 16 :  0.07651284887616262
# cost at iteration 17 :  0.07641649521832189
# cost at iteration 18 :  0.0763201847066635
# cost at iteration 19 :  0.07622391992668236
# cost at iteration 20 :  0.0761277034524124
# cost at iteration 21 :  0.07603153784696226
# cost at iteration 15 :  0.07660924308268023
# cost at iteration 16 :  0.07651284887616262
# cost at iteration 17 :  0.07641649521832189
# cost at iteration 18 :  0.0763201847066635
# cost at iteration 19 :  0.07622391992668236
# cost at iteration 20 :  0.0761277034524124
# cost at iteration 21 :  0.07603153784696226
# cost at iteration 22 :  0.07593542566303862
# cost at iteration 23 :  0.07583936944345575
# cost at iteration 24 :  0.07574337172163323
# cost at iteration 25 :  0.07564743502208099
# cost at iteration 26 :  0.07555156186087239
# cost at iteration 27 :  0.07545575474610558
# cost at iteration 28 :  0.07536001617835307
# cost at iteration 22 :  0.07593542566303862
# cost at iteration 23 :  0.07583936944345575
# cost at iteration 24 :  0.07574337172163323
# cost at iteration 25 :  0.07564743502208099
# cost at iteration 26 :  0.07555156186087239
# cost at iteration 27 :  0.07545575474610558
# cost at iteration 28 :  0.07536001617835307
# cost at iteration 29 :  0.07526434865110064
# cost at iteration 30 :  0.0751687546511745
# cost at iteration 31 :  0.07507323665915815
# cost at iteration 32 :  0.07497779714979902
# cost at iteration 33 :  0.07488243859240401
# cost at iteration 34 :  0.07478716345122573
# cost at iteration 35 :  0.07469197418583867
# cost at iteration 29 :  0.07526434865110064
# cost at iteration 30 :  0.0751687546511745
# cost at iteration 31 :  0.07507323665915815
# cost at iteration 32 :  0.07497779714979902
# cost at iteration 33 :  0.07488243859240401
# cost at iteration 34 :  0.07478716345122573
# cost at iteration 35 :  0.07469197418583867
# cost at iteration 36 :  0.07459687325150592
# cost at iteration 37 :  0.07450186309953641
# cost at iteration 38 :  0.07440694617763315
# cost at iteration 39 :  0.07431212493023269
# cost at iteration 36 :  0.07459687325150592
# cost at iteration 37 :  0.07450186309953641
# cost at iteration 38 :  0.07440694617763315
# cost at iteration 39 :  0.07431212493023269
# cost at iteration 40 :  0.07421740179883554
# cost at iteration 41 :  0.07412277922232866
# cost at iteration 42 :  0.07402825963729923
# cost at iteration 43 :  0.07393384547834057
# cost at iteration 40 :  0.07421740179883554
# cost at iteration 41 :  0.07412277922232866
# cost at iteration 42 :  0.07402825963729923
# cost at iteration 43 :  0.07393384547834057
# cost at iteration 44 :  0.0738395391783503
# cost at iteration 45 :  0.07374534316882053
# cost at iteration 46 :  0.07365125988012108
# cost at iteration 47 :  0.0735572917417748
# cost at iteration 48 :  0.0734634411827264
# cost at iteration 49 :  0.07336971063160395
# cost at iteration 44 :  0.0738395391783503
# cost at iteration 45 :  0.07374534316882053
# cost at iteration 46 :  0.07365125988012108
# cost at iteration 47 :  0.0735572917417748
# cost at iteration 48 :  0.0734634411827264
# cost at iteration 49 :  0.07336971063160395
# cost at iteration 50 :  0.07327610251697382
# cost at iteration 51 :  0.07318261926758908
# cost at iteration 52 :  0.07308926331263124
# cost at iteration 53 :  0.07299603708194621
# cost at iteration 54 :  0.07290294300627384
# cost at iteration 55 :  0.07280998351747159
# cost at iteration 56 :  0.0727171610487325
# cost at iteration 57 :  0.07262447803479764
# cost at iteration 50 :  0.07327610251697382
# cost at iteration 51 :  0.07318261926758908
# cost at iteration 52 :  0.07308926331263124
# cost at iteration 53 :  0.07299603708194621
# cost at iteration 54 :  0.07290294300627384
# cost at iteration 55 :  0.07280998351747159
# cost at iteration 56 :  0.0727171610487325
# cost at iteration 57 :  0.07262447803479764
# cost at iteration 58 :  0.07253193691216303
# cost at iteration 59 :  0.07243954011928105
# cost at iteration 60 :  0.072347290096757
# cost at iteration 61 :  0.07225518928754034
# cost at iteration 58 :  0.07253193691216303
# cost at iteration 59 :  0.07243954011928105
# cost at iteration 60 :  0.072347290096757
# cost at iteration 61 :  0.07225518928754034
# cost at iteration 62 :  0.07216324013711134
# cost at iteration 63 :  0.07207144509366269
# cost at iteration 64 :  0.07197980660827645
# cost at iteration 65 :  0.07188832713509671
# cost at iteration 66 :  0.07179700913149759
# cost at iteration 67 :  0.07170585505824732
# cost at iteration 68 :  0.07161486737966771
# cost at iteration 62 :  0.07216324013711134
# cost at iteration 63 :  0.07207144509366269
# cost at iteration 64 :  0.07197980660827645
# cost at iteration 65 :  0.07188832713509671
# cost at iteration 66 :  0.07179700913149759
# cost at iteration 67 :  0.07170585505824732
# cost at iteration 68 :  0.07161486737966771
# cost at iteration 69 :  0.07152404856378984
# cost at iteration 70 :  0.07143340108250583
# cost at iteration 71 :  0.07134292741171665
# cost at iteration 72 :  0.0712526300314763
# cost at iteration 73 :  0.07116251142613222
# cost at iteration 74 :  0.07107257408446256
# cost at iteration 75 :  0.07098282049980931
# cost at iteration 69 :  0.07152404856378984
# cost at iteration 70 :  0.07143340108250583
# cost at iteration 71 :  0.07134292741171665
# cost at iteration 72 :  0.0712526300314763
# cost at iteration 73 :  0.07116251142613222
# cost at iteration 74 :  0.07107257408446256
# cost at iteration 75 :  0.07098282049980931
# cost at iteration 76 :  0.07089325317020889
# cost at iteration 77 :  0.07080387459851899
# cost at iteration 78 :  0.07071468729254247
# cost at iteration 79 :  0.07062569376514799
# cost at iteration 80 :  0.07053689653438794
# cost at iteration 81 :  0.07044829812361325
# cost at iteration 82 :  0.07035990106158557
# cost at iteration 76 :  0.07089325317020889
# cost at iteration 77 :  0.07080387459851899
# cost at iteration 78 :  0.07071468729254247
# cost at iteration 79 :  0.07062569376514799
# cost at iteration 80 :  0.07053689653438794
# cost at iteration 81 :  0.07044829812361325
# cost at iteration 82 :  0.07035990106158557
# cost at iteration 83 :  0.07027170788258648
# cost at iteration 84 :  0.07018372112652417
# cost at iteration 85 :  0.07009594333903763
# cost at iteration 86 :  0.07000837707159818
# cost at iteration 87 :  0.06992102488160844
# cost at iteration 88 :  0.0698338893324994
# cost at iteration 89 :  0.06974697299382449
# cost at iteration 90 :  0.06966027844135206
# cost at iteration 91 :  0.06957380825715521
# cost at iteration 83 :  0.07027170788258648
# cost at iteration 84 :  0.07018372112652417
# cost at iteration 85 :  0.07009594333903763
# cost at iteration 86 :  0.07000837707159818
# cost at iteration 87 :  0.06992102488160844
# cost at iteration 88 :  0.0698338893324994
# cost at iteration 89 :  0.06974697299382449
# cost at iteration 90 :  0.06966027844135206
# cost at iteration 91 :  0.06957380825715521
# cost at iteration 92 :  0.06948756502969983
# cost at iteration 93 :  0.0694015513539302
# cost at iteration 94 :  0.06931576983135297
# cost at iteration 95 :  0.06923022307011911
# cost at iteration 96 :  0.0691449136851036
# cost at iteration 97 :  0.06905984429798388
# cost at iteration 98 :  0.06897501753731597
# cost at iteration 99 :  0.06889043603860916
# cost at iteration 100 :  0.06880610244439891
# cost at iteration 92 :  0.06948756502969983
# cost at iteration 93 :  0.0694015513539302
# cost at iteration 94 :  0.06931576983135297
# cost at iteration 95 :  0.06923022307011911
# cost at iteration 96 :  0.0691449136851036
# cost at iteration 97 :  0.06905984429798388
# cost at iteration 98 :  0.06897501753731597
# cost at iteration 99 :  0.06889043603860916
# cost at iteration 100 :  0.06880610244439891
# cost at iteration 101 :  0.06872201940431817
# cost at iteration 102 :  0.06863818957516697
# cost at iteration 103 :  0.06855461562098066
# cost at iteration 104 :  0.06847130021309629
# cost at iteration 105 :  0.06838824603021798
# cost at iteration 106 :  0.0683054557584807
# cost at iteration 107 :  0.06822293209151223
# cost at iteration 108 :  0.06814067773049459
# cost at iteration 109 :  0.0680586953842234
# cost at iteration 110 :  0.06797698776916637
# cost at iteration 111 :  0.06789555760952058
# cost at iteration 101 :  0.06872201940431817
# cost at iteration 102 :  0.06863818957516697
# cost at iteration 103 :  0.06855461562098066
# cost at iteration 104 :  0.06847130021309629
# cost at iteration 105 :  0.06838824603021798
# cost at iteration 106 :  0.0683054557584807
# cost at iteration 107 :  0.06822293209151223
# cost at iteration 108 :  0.06814067773049459
# cost at iteration 109 :  0.0680586953842234
# cost at iteration 110 :  0.06797698776916637
# cost at iteration 111 :  0.06789555760952058
# cost at iteration 112 :  0.0678144076372682
# cost at iteration 113 :  0.06773354059223158
# cost at iteration 114 :  0.06765295922212661
# cost at iteration 115 :  0.06757266628261546
# cost at iteration 116 :  0.06749266453735804
# cost at iteration 117 :  0.06741295675806219
# cost at iteration 118 :  0.06733354572453353
# cost at iteration 112 :  0.0678144076372682
# cost at iteration 113 :  0.06773354059223158
# cost at iteration 114 :  0.06765295922212661
# cost at iteration 115 :  0.06757266628261546
# cost at iteration 116 :  0.06749266453735804
# cost at iteration 117 :  0.06741295675806219
# cost at iteration 118 :  0.06733354572453353
# cost at iteration 119 :  0.06725443422472338
# cost at iteration 120 :  0.06717562505477663
# cost at iteration 121 :  0.06709712101907805
# cost at iteration 122 :  0.06701892493029796
# cost at iteration 123 :  0.06694103960943691
# cost at iteration 124 :  0.06686346788586965
# cost at iteration 125 :  0.0667862125973882
# cost at iteration 119 :  0.06725443422472338
# cost at iteration 120 :  0.06717562505477663
# cost at iteration 121 :  0.06709712101907805
# cost at iteration 122 :  0.06701892493029796
# cost at iteration 123 :  0.06694103960943691
# cost at iteration 124 :  0.06686346788586965
# cost at iteration 125 :  0.0667862125973882
# cost at iteration 126 :  0.06670927659024385
# cost at iteration 127 :  0.06663266271918893
# cost at iteration 128 :  0.0665563738475171
# cost at iteration 129 :  0.06648041284710371
# cost at iteration 130 :  0.06640478259844461
# cost at iteration 131 :  0.06632948599069488
# cost at iteration 126 :  0.06670927659024385
# cost at iteration 127 :  0.06663266271918893
# cost at iteration 128 :  0.0665563738475171
# cost at iteration 129 :  0.06648041284710371
# cost at iteration 130 :  0.06640478259844461
# cost at iteration 131 :  0.06632948599069488
# cost at iteration 132 :  0.06625452592170654
# cost at iteration 133 :  0.06617990529806575
# cost at iteration 134 :  0.06610562703512925
# cost at iteration 135 :  0.06603169405706019
# cost at iteration 136 :  0.06595810929686355
# cost at iteration 137 :  0.06588487569642057
# cost at iteration 132 :  0.06625452592170654
# cost at iteration 133 :  0.06617990529806575
# cost at iteration 134 :  0.06610562703512925
# cost at iteration 135 :  0.06603169405706019
# cost at iteration 136 :  0.06595810929686355
# cost at iteration 137 :  0.06588487569642057
# cost at iteration 138 :  0.06581199620652305
# cost at iteration 139 :  0.06573947378690664
# cost at iteration 140 :  0.06566731140628403
# cost at iteration 141 :  0.06559551204237714
# cost at iteration 142 :  0.06552407868194927
# cost at iteration 143 :  0.06545301432083643
# cost at iteration 144 :  0.06538232196397824
# cost at iteration 138 :  0.06581199620652305
# cost at iteration 139 :  0.06573947378690664
# cost at iteration 140 :  0.06566731140628403
# cost at iteration 141 :  0.06559551204237714
# cost at iteration 142 :  0.06552407868194927
# cost at iteration 143 :  0.06545301432083643
# cost at iteration 144 :  0.06538232196397824
# cost at iteration 145 :  0.06531200462544838
# cost at iteration 146 :  0.06524206532848464
# cost at iteration 147 :  0.06517250710551847
# cost at iteration 148 :  0.06510333299820406
# cost at iteration 149 :  0.06503454605744709
# cost at iteration 150 :  0.06496614934343285
# cost at iteration 151 :  0.06489814592565443
# cost at iteration 145 :  0.06531200462544838
# cost at iteration 146 :  0.06524206532848464
# cost at iteration 147 :  0.06517250710551847
# cost at iteration 148 :  0.06510333299820406
# cost at iteration 149 :  0.06503454605744709
# cost at iteration 150 :  0.06496614934343285
# cost at iteration 151 :  0.06489814592565443
# cost at iteration 152 :  0.06483053888293995
# cost at iteration 153 :  0.0647633313034798
# cost at iteration 154 :  0.06469652628485348
# cost at iteration 155 :  0.06463012693405581
# cost at iteration 156 :  0.06456413636752321
# cost at iteration 157 :  0.06449855771115938
# cost at iteration 152 :  0.06483053888293995
# cost at iteration 153 :  0.0647633313034798
# cost at iteration 154 :  0.06469652628485348
# cost at iteration 155 :  0.06463012693405581
# cost at iteration 156 :  0.06456413636752321
# cost at iteration 157 :  0.06449855771115938
# cost at iteration 158 :  0.0644333941003606
# cost at iteration 159 :  0.06436864868004097
# cost at iteration 160 :  0.06430432460465724
# cost at iteration 161 :  0.06424042503823317
# cost at iteration 162 :  0.06417695315438383
# cost at iteration 163 :  0.06411391213633953
# cost at iteration 164 :  0.06405130517696958
# cost at iteration 165 :  0.06398913547880544
# cost at iteration 158 :  0.0644333941003606
# cost at iteration 159 :  0.06436864868004097
# cost at iteration 160 :  0.06430432460465724
# cost at iteration 161 :  0.06424042503823317
# cost at iteration 162 :  0.06417695315438383
# cost at iteration 163 :  0.06411391213633953
# cost at iteration 164 :  0.06405130517696958
# cost at iteration 165 :  0.06398913547880544
# cost at iteration 166 :  0.06392740625406416
# cost at iteration 167 :  0.06386612072467117
# cost at iteration 168 :  0.06380528212228276
# cost at iteration 169 :  0.06374489368830873
# cost at iteration 170 :  0.06368495867393449
# cost at iteration 171 :  0.06362548034014295
# cost at iteration 172 :  0.06356646195773621
# cost at iteration 166 :  0.06392740625406416
# cost at iteration 167 :  0.06386612072467117
# cost at iteration 168 :  0.06380528212228276
# cost at iteration 169 :  0.06374489368830873
# cost at iteration 170 :  0.06368495867393449
# cost at iteration 171 :  0.06362548034014295
# cost at iteration 172 :  0.06356646195773621
# cost at iteration 173 :  0.0635079068073572
# cost at iteration 174 :  0.0634498181795108
# cost at iteration 175 :  0.06339219937458483
# cost at iteration 176 :  0.06333505370287112
# cost at iteration 177 :  0.06327838448458584
# cost at iteration 178 :  0.06322219504988992
# cost at iteration 173 :  0.0635079068073572
# cost at iteration 174 :  0.0634498181795108
# cost at iteration 175 :  0.06339219937458483
# cost at iteration 176 :  0.06333505370287112
# cost at iteration 177 :  0.06327838448458584
# cost at iteration 178 :  0.06322219504988992
# cost at iteration 179 :  0.06316648873890923
# cost at iteration 180 :  0.06311126890175445
# cost at iteration 181 :  0.06305653889854068
# cost at iteration 182 :  0.06300230209940691
# cost at iteration 183 :  0.06294856188453486
# cost at iteration 184 :  0.06289532164416815
# cost at iteration 185 :  0.06284258477863061
# cost at iteration 179 :  0.06316648873890923
# cost at iteration 180 :  0.06311126890175445
# cost at iteration 181 :  0.06305653889854068
# cost at iteration 182 :  0.06300230209940691
# cost at iteration 183 :  0.06294856188453486
# cost at iteration 184 :  0.06289532164416815
# cost at iteration 185 :  0.06284258477863061
# cost at iteration 186 :  0.06279035469834451
# cost at iteration 187 :  0.06273863482384849
# cost at iteration 188 :  0.0626874285858148
# cost at iteration 189 :  0.06263673942506665
# cost at iteration 190 :  0.06258657079259455
# cost at iteration 191 :  0.06253692614957261
# cost at iteration 192 :  0.0624878089673739
# cost at iteration 186 :  0.06279035469834451
# cost at iteration 187 :  0.06273863482384849
# cost at iteration 188 :  0.0626874285858148
# cost at iteration 189 :  0.06263673942506665
# cost at iteration 190 :  0.06258657079259455
# cost at iteration 191 :  0.06253692614957261
# cost at iteration 192 :  0.0624878089673739
# cost at iteration 193 :  0.06243922272758546
# cost at iteration 194 :  0.062391170922022614
# cost at iteration 195 :  0.06234365705274235
# cost at iteration 196 :  0.06229668463205594
# cost at iteration 197 :  0.06225025718254069
# cost at iteration 198 :  0.062204378237050335
# cost at iteration 199 :  0.062159051338724645
# cost at iteration 193 :  0.06243922272758546
# cost at iteration 194 :  0.062391170922022614
# cost at iteration 195 :  0.06234365705274235
# cost at iteration 196 :  0.06229668463205594
# cost at iteration 197 :  0.06225025718254069
# cost at iteration 198 :  0.062204378237050335
# cost at iteration 199 :  0.062159051338724645
# cost at iteration 200 :  0.06211428004099704
# cost at iteration 201 :  0.06207006790760129
# cost at iteration 202 :  0.06202641851257585
# cost at iteration 203 :  0.06198333544026656
# cost at iteration 204 :  0.06194082228532687
# cost at iteration 205 :  0.061898882652715426
# cost at iteration 206 :  0.06185752015769067
# cost at iteration 200 :  0.06211428004099704
# cost at iteration 201 :  0.06207006790760129
# cost at iteration 202 :  0.06202641851257585
# cost at iteration 203 :  0.06198333544026656
# cost at iteration 204 :  0.06194082228532687
# cost at iteration 205 :  0.061898882652715426
# cost at iteration 206 :  0.06185752015769067
# cost at iteration 207 :  0.061816738425801994
# cost at iteration 208 :  0.06177654109287712
# cost at iteration 209 :  0.061736931805004544
# cost at iteration 210 :  0.06169791421851133
# cost at iteration 211 :  0.06165949199993462
# cost at iteration 212 :  0.061621668825986305
# cost at iteration 213 :  0.061584448383510015
# cost at iteration 207 :  0.061816738425801994
# cost at iteration 208 :  0.06177654109287712
# cost at iteration 209 :  0.061736931805004544
# cost at iteration 210 :  0.06169791421851133
# cost at iteration 211 :  0.06165949199993462
# cost at iteration 212 :  0.061621668825986305
# cost at iteration 213 :  0.061584448383510015
# cost at iteration 214 :  0.06154783436942869
# cost at iteration 215 :  0.06151183049068177
# cost at iteration 216 :  0.06147644046415018
# cost at iteration 217 :  0.0614416680165667
# cost at iteration 214 :  0.06154783436942869
# cost at iteration 215 :  0.06151183049068177
# cost at iteration 216 :  0.06147644046415018
# cost at iteration 217 :  0.0614416680165667
# cost at iteration 218 :  0.06140751688441042
# cost at iteration 219 :  0.06137399081378122
# cost at iteration 220 :  0.061341093560251934
# cost at iteration 221 :  0.061308828888693885
# cost at iteration 222 :  0.061277200573071115
# cost at iteration 223 :  0.06124621239619799
# cost at iteration 224 :  0.061215868149452984
# cost at iteration 218 :  0.06140751688441042
# cost at iteration 219 :  0.06137399081378122
# cost at iteration 220 :  0.061341093560251934
# cost at iteration 221 :  0.061308828888693885
# cost at iteration 222 :  0.061277200573071115
# cost at iteration 223 :  0.06124621239619799
# cost at iteration 224 :  0.061215868149452984
# cost at iteration 225 :  0.061186171632440806
# cost at iteration 226 :  0.06115712665259294
# cost at iteration 227 :  0.06112873702469433
# cost at iteration 228 :  0.06110100657032171
# cost at iteration 229 :  0.061073939117175166
# cost at iteration 230 :  0.061047538498280346
# cost at iteration 231 :  0.06102180855103373
# cost at iteration 225 :  0.061186171632440806
# cost at iteration 226 :  0.06115712665259294
# cost at iteration 227 :  0.06112873702469433
# cost at iteration 228 :  0.06110100657032171
# cost at iteration 229 :  0.061073939117175166
# cost at iteration 230 :  0.061047538498280346
# cost at iteration 231 :  0.06102180855103373
# cost at iteration 232 :  0.06099675311605498
# cost at iteration 233 :  0.06097237603580311
# cost at iteration 234 :  0.06094868115289963
# cost at iteration 235 :  0.060925672308086404
# cost at iteration 236 :  0.060903353337726895
# cost at iteration 237 :  0.06088172807072895
# cost at iteration 238 :  0.06086080032473191
# cost at iteration 232 :  0.06099675311605498
# cost at iteration 233 :  0.06097237603580311
# cost at iteration 234 :  0.06094868115289963
# cost at iteration 235 :  0.060925672308086404
# cost at iteration 236 :  0.060903353337726895
# cost at iteration 237 :  0.06088172807072895
# cost at iteration 238 :  0.06086080032473191
# cost at iteration 239 :  0.06084057390134873
# cost at iteration 240 :  0.06082105258018312
# cost at iteration 241 :  0.06080224011124221
# cost at iteration 242 :  0.060784140205226114
# cost at iteration 243 :  0.06076675652097309
# cost at iteration 244 :  0.06075009264904463
# cost at iteration 245 :  0.060734152089998404
# cost at iteration 239 :  0.06084057390134873
# cost at iteration 240 :  0.06082105258018312
# cost at iteration 241 :  0.06080224011124221
# cost at iteration 242 :  0.060784140205226114
# cost at iteration 243 :  0.06076675652097309
# cost at iteration 244 :  0.06075009264904463
# cost at iteration 245 :  0.060734152089998404
# cost at iteration 246 :  0.06071893822523646
# cost at iteration 247 :  0.06070445427729702
# cost at iteration 248 :  0.06069070325485559
# cost at iteration 249 :  0.06067768787511364
# cost at iteration 250 :  0.06066541045197177
# cost at iteration 251 :  0.060653872731091976
# cost at iteration 252 :  0.06064307564013572
# cost at iteration 246 :  0.06071893822523646
# cost at iteration 247 :  0.06070445427729702
# cost at iteration 248 :  0.06069070325485559
# cost at iteration 249 :  0.06067768787511364
# cost at iteration 250 :  0.06066541045197177
# cost at iteration 251 :  0.060653872731091976
# cost at iteration 252 :  0.06064307564013572
# cost at iteration 253 :  0.06063301889912494
# cost at iteration 254 :  0.060623700391689815
# cost at iteration 255 :  0.06061511511059371
# cost at iteration 256 :  0.06060725330953516
# cost at iteration 257 :  0.060600097095771764
# cost at iteration 258 :  0.060593613774174854
# cost at iteration 259 :  0.060587741967913424
# cost at iteration 260 :  0.06058236055287204
# cost at iteration 253 :  0.06063301889912494
# cost at iteration 254 :  0.060623700391689815
# cost at iteration 255 :  0.06061511511059371
# cost at iteration 256 :  0.06060725330953516
# cost at iteration 257 :  0.060600097095771764
# cost at iteration 258 :  0.060593613774174854
# cost at iteration 259 :  0.060587741967913424
# cost at iteration 260 :  0.06058236055287204
# cost at iteration 261 :  0.06057721431715532
# cost at iteration 262 :  0.06057173124939393
# cost at iteration 263 :  0.060564643692288436
# cost at iteration 264 :  0.0605539957225843
# cost at iteration 265 :  0.06054068996982605
# cost at iteration 266 :  0.06053056141741087
# cost at iteration 267 :  0.060524874366219526
# cost at iteration 261 :  0.06057721431715532
# cost at iteration 262 :  0.06057173124939393
# cost at iteration 263 :  0.060564643692288436
# cost at iteration 264 :  0.0605539957225843
# cost at iteration 265 :  0.06054068996982605
# cost at iteration 266 :  0.06053056141741087
# cost at iteration 267 :  0.060524874366219526
# cost at iteration 268 :  0.060521498469586085
# cost at iteration 269 :  0.06051913234760086
# cost at iteration 270 :  0.060517225060261505
# cost at iteration 271 :  0.06051555286498391
# cost at iteration 272 :  0.06051402638941127
# cost at iteration 273 :  0.06051261037771087
# cost at iteration 268 :  0.060521498469586085
# cost at iteration 269 :  0.06051913234760086
# cost at iteration 270 :  0.060517225060261505
# cost at iteration 271 :  0.06051555286498391
# cost at iteration 272 :  0.06051402638941127
# cost at iteration 273 :  0.06051261037771087
# cost at iteration 274 :  0.060511290531236536
# cost at iteration 275 :  0.060510060193157265
# cost at iteration 276 :  0.06050891525499296
# cost at iteration 277 :  0.06050785232581172
# cost at iteration 278 :  0.06050686812309921
# cost at iteration 279 :  0.06050595929203448
# cost at iteration 280 :  0.06050512236566823
# cost at iteration 274 :  0.060511290531236536
# cost at iteration 275 :  0.060510060193157265
# cost at iteration 276 :  0.06050891525499296
# cost at iteration 277 :  0.06050785232581172
# cost at iteration 278 :  0.06050686812309921
# cost at iteration 279 :  0.06050595929203448
# cost at iteration 280 :  0.06050512236566823
# cost at iteration 281 :  0.06050435376980091
# cost at iteration 282 :  0.060503649843069135
# cost at iteration 283 :  0.060503006863879466
# cost at iteration 284 :  0.0605024210817393
# cost at iteration 285 :  0.06050188875186703
# cost at iteration 286 :  0.06050140617210032
# cost at iteration 287 :  0.06050096972102538
# cost at iteration 281 :  0.06050435376980091
# cost at iteration 282 :  0.060503649843069135
# cost at iteration 283 :  0.060503006863879466
# cost at iteration 284 :  0.0605024210817393
# cost at iteration 285 :  0.06050188875186703
# cost at iteration 286 :  0.06050140617210032
# cost at iteration 287 :  0.06050096972102538
# cost at iteration 288 :  0.06050057589617722
# cost at iteration 289 :  0.060500221351165125
# cost at iteration 290 :  0.06049990293066571
# cost at iteration 291 :  0.060499617702371916
# cost at iteration 292 :  0.06049936298516272
# cost at iteration 293 :  0.06049913637291608
# cost at iteration 294 :  0.060498935753492133
# cost at iteration 288 :  0.06050057589617722
# cost at iteration 289 :  0.060500221351165125
# cost at iteration 290 :  0.06049990293066571
# cost at iteration 291 :  0.060499617702371916
# cost at iteration 292 :  0.06049936298516272
# cost at iteration 293 :  0.06049913637291608
# cost at iteration 294 :  0.060498935753492133
# cost at iteration 295 :  0.060498759322435154
# cost at iteration 296 :  0.060498605590875415
# cost at iteration 297 :  0.06049847338698318
# cost at iteration 298 :  0.060498361850198516
# cost at iteration 299 :  0.06049827041743197
# cost at iteration 300 :  0.06049819880061843
# cost at iteration 295 :  0.060498759322435154
# cost at iteration 296 :  0.060498605590875415
# cost at iteration 297 :  0.06049847338698318
# cost at iteration 298 :  0.060498361850198516
# cost at iteration 299 :  0.06049827041743197
# cost at iteration 300 :  0.06049819880061843
# cost at iteration 301 :  0.06049814695551413
# cost at iteration 302 :  0.06049811504248504
# cost at iteration 303 :  0.060498103381164424
# scale =  6.049147512285278
# New cost during line search:  0.06049976541606705
# scale =  3.024573756142639
# New cost during line search:  0.06049978122925711
# scale =  1.5122868780713195
# New cost during line search:  0.06049978940045375
# scale =  0.7561434390356597
# New cost during line search:  0.06049979355227652
# scale =  0.37807171951782986
# New cost during line search:  0.060499795644753225
# scale =  0.18903585975891493
# New cost during line search:  0.06049979669513405
# scale =  0.09451792987945747
# New cost during line search:  0.060499797221360195
# scale =  0.04725896493972873
# New cost during line search:  0.06049979748473224
# scale =  0.023629482469864366
# New cost during line search:  0.060499797616483005
# scale =  0.011814741234932183
# New cost during line search:  0.06049979768237459
# scale =  0.005907370617466092
# New cost during line search:  0.06049979771532441
# scale =  0.002953685308733046
# New cost during line search:  0.06049979773180034
# scale =  0.001476842654366523
# New cost during line search:  0.06049979774003857
# scale =  0.0007384213271832615
# New cost during line search:  0.06049979774415773
# scale =  0.0003692106635916307
# New cost during line search:  0.060499797746217346
# scale =  0.00018460533179581536
# New cost during line search:  0.06049979774724709
# scale =  9.230266589790768e-05
# New cost during line search:  0.060499797747762055
# scale =  4.615133294895384e-05
# New cost during line search:  0.060499797748019474
# scale =  2.307566647447692e-05
# New cost during line search:  0.06049979774814821
# scale =  1.153783323723846e-05
# New cost during line search:  0.060499797748212576
# scale =  5.76891661861923e-06
# New cost during line search:  0.060499797748244766
# scale =  2.884458309309615e-06
# New cost during line search:  0.06049979774826087
# scale =  1.4422291546548075e-06
# cost at iteration 301 :  0.06049814695551413
# cost at iteration 302 :  0.06049811504248504
# cost at iteration 303 :  0.060498103381164424
# scale =  6.049147512285278
# New cost during line search:  0.06049976541606705
# scale =  3.024573756142639
# New cost during line search:  0.06049978122925711
# scale =  1.5122868780713195
# New cost during line search:  0.06049978940045375
# scale =  0.7561434390356597
# New cost during line search:  0.06049979355227652
# scale =  0.37807171951782986
# New cost during line search:  0.060499795644753225
# scale =  0.18903585975891493
# New cost during line search:  0.06049979669513405
# scale =  0.09451792987945747
# New cost during line search:  0.060499797221360195
# scale =  0.04725896493972873
# New cost during line search:  0.06049979748473224
# scale =  0.023629482469864366
# New cost during line search:  0.060499797616483005
# scale =  0.011814741234932183
# New cost during line search:  0.06049979768237459
# scale =  0.005907370617466092
# New cost during line search:  0.06049979771532441
# scale =  0.002953685308733046
# New cost during line search:  0.06049979773180034
# scale =  0.001476842654366523
# New cost during line search:  0.06049979774003857
# scale =  0.0007384213271832615
# New cost during line search:  0.06049979774415773
# scale =  0.0003692106635916307
# New cost during line search:  0.060499797746217346
# scale =  0.00018460533179581536
# New cost during line search:  0.06049979774724709
# scale =  9.230266589790768e-05
# New cost during line search:  0.060499797747762055
# scale =  4.615133294895384e-05
# New cost during line search:  0.060499797748019474
# scale =  2.307566647447692e-05
# New cost during line search:  0.06049979774814821
# scale =  1.153783323723846e-05
# New cost during line search:  0.060499797748212576
# scale =  5.76891661861923e-06
# New cost during line search:  0.060499797748244766
# scale =  2.884458309309615e-06
# New cost during line search:  0.06049979774826087
# scale =  1.4422291546548075e-06
# New cost during line search:  0.06049979774826891
# scale =  7.211145773274038e-07
# New cost during line search:  0.0604997977482729
# scale =  3.605572886637019e-07
# New cost during line search:  0.060499797748274915
# scale =  1.8027864433185094e-07
# New cost during line search:  0.060499797748275935
# scale =  9.013932216592547e-08
# New cost during line search:  0.06049979774827642
# scale =  4.5069661082962735e-08
# New cost during line search:  0.06049979774827667
# scale =  2.2534830541481368e-08
# New cost during line search:  0.06049979774827681
# scale =  1.1267415270740684e-08
# New cost during line search:  0.06049979774827686
# scale =  5.633707635370342e-09
# New cost during line search:  0.060499797748276886
# scale =  2.816853817685171e-09
# New cost during line search:  0.06049979774827694
# scale =  1.4084269088425855e-09
# New cost during line search:  0.06049979774827694
# scale =  7.042134544212927e-10
# New cost during line search:  0.06049979774827692
# scale =  3.5210672721064637e-10
# New cost during line search:  0.060499797748276934
# scale =  1.7605336360532318e-10
# New cost during line search:  0.06049979774827694
# scale =  8.802668180266159e-11
# New cost during line search:  0.06049979774827692
# scale =  4.4013340901330796e-11
# New cost during line search:  0.06049979774827693
# scale =  2.2006670450665398e-11
# New cost during line search:  0.060499797748276914
# scale =  1.1003335225332699e-11
# New cost during line search:  0.060499797748276914
# scale =  5.5016676126663495e-12
# New cost during line search:  0.0604997977482769
# scale =  2.7508338063331747e-12
# New cost during line search:  0.06049979774827692
# scale =  1.3754169031665874e-12
# New cost during line search:  0.06049979774827693
# scale =  6.877084515832937e-13
# No more descent can be found
# Norm of gset 0.10250601603373334
# New cost during line search:  0.06049979774826891
# scale =  7.211145773274038e-07
# New cost during line search:  0.0604997977482729
# scale =  3.605572886637019e-07
# New cost during line search:  0.060499797748274915
# scale =  1.8027864433185094e-07
# New cost during line search:  0.060499797748275935
# scale =  9.013932216592547e-08
# New cost during line search:  0.06049979774827642
# scale =  4.5069661082962735e-08
# New cost during line search:  0.06049979774827667
# scale =  2.2534830541481368e-08
# New cost during line search:  0.06049979774827681
# scale =  1.1267415270740684e-08
# New cost during line search:  0.06049979774827686
# scale =  5.633707635370342e-09
# New cost during line search:  0.060499797748276886
# scale =  2.816853817685171e-09
# New cost during line search:  0.06049979774827694
# scale =  1.4084269088425855e-09
# New cost during line search:  0.06049979774827694
# scale =  7.042134544212927e-10
# New cost during line search:  0.06049979774827692
# scale =  3.5210672721064637e-10
# New cost during line search:  0.060499797748276934
# scale =  1.7605336360532318e-10
# New cost during line search:  0.06049979774827694
# scale =  8.802668180266159e-11
# New cost during line search:  0.06049979774827692
# scale =  4.4013340901330796e-11
# New cost during line search:  0.06049979774827693
# scale =  2.2006670450665398e-11
# New cost during line search:  0.060499797748276914
# scale =  1.1003335225332699e-11
# New cost during line search:  0.060499797748276914
# scale =  5.5016676126663495e-12
# New cost during line search:  0.0604997977482769
# scale =  2.7508338063331747e-12
# New cost during line search:  0.06049979774827692
# scale =  1.3754169031665874e-12
# New cost during line search:  0.06049979774827693
# scale =  6.877084515832937e-13
# No more descent can be found
# Norm of gset 0.10250601603373334
