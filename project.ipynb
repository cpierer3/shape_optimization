# %%
from ngsolve import *
from netgen.occ import *
from ngsolve.webgui import Draw
import matplotlib.pyplot as plt
from netgen.geom2d import SplineGeometry
import numpy as np
from ngsolve.nonlinearsolvers import Newton

# %% [markdown]
# We want to solve the PDE-constrained shape optimization problem
#
# $$
# \min_{\Omega \subset \mathsf{D}} J(u)
# := \int_\Omega |\nabla u_\Omega - \nabla u_{ref}|^2 \, dx
# $$
#
# subject to $(\Omega,u_\Omega)$ satisfying
#
# $$
# \int_\Omega \nabla u_\Omega \cdot \nabla v + u_\Omega v \, dx
# =
# \int_\Omega f v \, dx
# \quad \text{for all } v \in H_0^1(\Omega),
# $$
#
# where $\Omega \subset \mathbb{R}^2$ and
# $u_d, f \in C^1(\mathbb{R}^2)$.

# %%
geo = OCCGeometry(Circle((0, 0), 1).Face(), dim=2).GenerateMesh(maxh=0.1)
mesh = Mesh(geo)
# #Draw(mesh)

# optimals shape is k lobed flower domain
 
# r = CoefficientFunction((x**2 + y**2)**0.5)
# theta = CoefficientFunction(atan2(y, x))
 
# # Anzahl der Blätter
# k = 6
# # Amplitude der Blätter
# A = 0.5
 
# ud = CF(1 - r**2 + A*cos(k*theta))  
# f  = CF(5 - r**2) 


a = 0.04
b = 0.06

ud = 1 - ((x-0.01)**2/a**2 + (y-0.01)**2/b**2)

f = (2/a**2 + 2/b**2) + ud
# #f = CF(1)

grad_f = CoefficientFunction( (f.Diff(x), f.Diff(y) ) )
grad_ud = CoefficientFunction( (ud.Diff(x), ud.Diff(y) ) )

Draw(ud, mesh, "target_function")
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# BaseWebGuiScene

# %%
fes = H1(mesh, order=2, dirichlet=".*")
u, v = fes.TnT()
gfu = GridFunction(fes)
scene_gfu = Draw (gfu, mesh, "state")

a = BilinearForm(fes, symmetric=True)
a += grad(u)*grad(v)*dx
a += u*v*dx

fstate = LinearForm(fes)
fstate += f*v*dx
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
def SolveStateEquation():
    rhs = gfu.vec.CreateVector()
    rhs.data = fstate.vec - a.mat * gfu.vec
    update = gfu.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()) * rhs
    gfu.vec.data += update

# %%
a.Assemble()
fstate.Assemble()
SolveStateEquation()
scene_gfu.Redraw()

# %% [markdown]
# ### Adjoint equation
#
# The adjoint p satisfies
#
# $$
# \int_\Omega \nabla w \cdot \nabla p + w p \, dx
# =
# -2 \int_\Omega (\nabla u_\Omega - \nabla u_{ref}) w
# \quad \text{for all } w \in H_0^1(\Omega),
# $$

# %%
def Cost(u):
    return InnerProduct(grad(u) - grad_ud, grad(u) - grad_ud) * dx

p, w = fes.TnT()
gfp = GridFunction(fes)
scene_gfp = Draw (gfp, mesh, "adjoint")

fadjoint = LinearForm(fes)
#fadjoint += -1*Cost(gfu).Diff(gfu,w)
fadjoint += -2* InnerProduct(grad(gfu) - grad_ud, grad(w)) * dx
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…

# %%
def SolveAdjointEquation():
    rhs = gfp.vec.CreateVector()
    rhs.data = fadjoint.vec - a.mat.T * gfp.vec
    update = gfp.vec.CreateVector()
    update.data = a.mat.Inverse(fes.FreeDofs()).T * rhs
    gfp.vec.data += update

# %%
fadjoint.Assemble()
SolveAdjointEquation()
scene_gfp.Redraw()

# %% [markdown]
# The shape derivative of the shape function
#
# $$
# \mathcal{J}(\Omega) := \int_\Omega |\nabla u - \nabla u_d|^2 \, dx
# $$
#
# at $\Omega$ in direction $X$ is given by
#
# $$
# \begin{aligned}
# DJ(\Omega)(X)
# &=
# \int_\Omega (\operatorname{div}(X)\,I - \partial X - \partial X^\top)|\nabla u - \nabla u_{\mathrm{ref}}|^2
# - 2 \int_\Omega (\nabla u - \nabla u_{\mathrm{ref}}) \nabla^2 u_{\mathrm{ref}} \cdot X\\
# &\quad
# + \int_\Omega \operatorname{div}(X) u p \\
# &\quad
# + \int_\Omega
# \bigl(\operatorname{div}(X)I - \partial X - \partial X^\top\bigr)
# \nabla u \cdot \nabla p \\
# &\quad
# - \int_\Omega (\nabla f \cdot X)\,p\\
# & \quad
# - \int_\Omega \operatorname{div}(X)fp .
# \end{aligned}
# $$
#
# We now assemble this shape derivative in NGSolve as follows:

# %%
# # gfs = GridFunction(VEC)
# # gfs.Set((1000, 1000))

# # mesh.SetDeformation(gfs)


# h = specialcf.mesh_size
# # print(Integrate(h, mesh, element_wise=True))

# # #help(Integrate)

# Draw(h, mesh)

# %%
def check_mesh_quality(mesh, gfSet=None):
    qualities = []
    try:
        for el in mesh.Elements(VOL):
            if len(el.vertices) != 3:
                continue

            try:
                p1_, p2_, p3_ = [mesh[v].point for v in el.vertices]

                if gfSet:
                    p1 = np.array(gfSet(mesh(p1_)))
                    p2 = np.array(gfSet(mesh(p2_)))
                    p3 = np.array(gfSet(mesh(p3_)))
                else:
                    p1 = np.array(p1_)
                    p2 = np.array(p2_)
                    p3 = np.array(p3_)

                a = np.linalg.norm(p2 - p1)
                b = np.linalg.norm(p3 - p2)
                c = np.linalg.norm(p1 - p3)

                qualities.append(max(a, b, c) / min(a, b, c))

            except Exception as e:
                print(f"Error processing element {el}: {e}")
                continue

        qualities = np.array(qualities)
        print(
            f"Mesh quality metrics (min, max, mean, median): "
            f"{np.min(qualities):.6f}, {np.max(qualities):.6f}, "
            f"{np.mean(qualities):.6f}, {np.median(qualities):.6f}"
        )

        # Warning for poor quality elements
        poor_quality = np.sum(qualities > 2)
        if poor_quality > 0:
            print(f"Warning: {poor_quality} elements with poor quality (>2)")

    
    except:
        pass

# %%
def hesse(u):
    return CoefficientFunction(
        (u.Diff(x).Diff(x), u.Diff(x).Diff(y),
         u.Diff(y).Diff(x), u.Diff(y).Diff(y)), 
        dims=(2,2)
    )

#VEC = H1(mesh, order=3, dirichlet=".*", dim=2)
VEC = H1(mesh, order=1, dim = 2)
X, PHI = VEC.TnT()

dJOmega = LinearForm(VEC)
dJOmega += InnerProduct((div(PHI)*(grad(gfu)- grad_ud)), grad(gfu)- grad_ud) * dx
dJOmega += -2* InnerProduct(hesse(ud)*PHI, grad(gfu)- grad_ud) * dx
dJOmega += div(PHI)* gfu *gfp *dx
dJOmega += InnerProduct(div(PHI)*grad(gfu), grad(gfp)) * dx
dJOmega += -InnerProduct(PHI.Deriv()*grad(gfu), grad(gfp)) * dx
dJOmega += -InnerProduct(grad(gfu), PHI.Deriv()*grad(gfp)) * dx
dJOmega += -div(PHI)* f * gfp * dx
dJOmega += -grad_f * PHI*gfp * dx

# %% [markdown]
# - Next, we want to find a vector field $X$ which yields a decrease of the objective
#   function, i.e. we want to find a vector field $X$ such that
#
#   $$
#   d\mathcal{J}(\Omega; X) < 0.
#   $$
#
# - This can be achieved by solving an auxiliary boundary value problem of the type
#
#   $$
#   \text{Find } X \in H :
#   \qquad
#   b(X, \Phi) = d\mathcal{J}(\Omega; \Phi)
#   \quad \text{for all } \Phi \in H,
#   $$
#
#   for a suitable Hilbert space $H$ (e.g. $H = H^1(\Omega)^2$).
#   Here, $b(\cdot,\cdot) : H \times H \to \mathbb{R}$ is a positive definite bilinear
#   form which we are free to choose. Then $-X$ is a descent direction since
#
#   $$
#   d\mathcal{J}(\Omega; -X)
#   = - d\mathcal{J}(\Omega; X)
#   = - b(X, X)
#   < 0.
#   $$
#
# - First we start with the bilinear form
#
#   $$
#   b(X, Y)
#   =
#   \int_\Omega \nabla X : \nabla Y + X \cdot Y \, dx .
#   $$
#
# - we can also choose X as
#   $$
#   \min _{X \in H^1_0(\Omega)} \frac{1}{p} \int _\Omega |\nabla X|^p - DJ(\Omega)(X)
#   $$
#
#   since this is a continous functional on $H^1_0(\Omega)'$, it is equivalent to finding $X \in H^1_0(\Omega)$ sucht that,
#
#   $$
#   \int _\Omega |\nabla X | ^{p-2}  \nabla X \cdot \nabla \Phi = DJ(\Omega)(\Phi) \qquad \forall \Phi \in H^1_0(\Omega)
#   $$

# %%
def pose_deformation_equation(gamma=None, p = None): 
    b = BilinearForm(VEC)
    if not p:
        b += InnerProduct(grad(X),grad(PHI))*dx + InnerProduct(X,PHI)*dx

    if gamma:
        print('Using gamma =', gamma)
        b = BilinearForm(VEC)
        b += (1.0/gamma)*InnerProduct(grad(X),grad(PHI))*dx + (1.0/gamma)*InnerProduct(X,PHI)*dx
        # Gamma regularisierung (korrigiert)
        b += InnerProduct(CF((-X[0].Diff(x)+X[1].Diff(y), X[0].Diff(y)+X[1].Diff(x))),
                                   CF((-PHI[0].Diff(x)+PHI[1].Diff(y), PHI[0].Diff(y)+PHI[1].Diff(x)))) * dx

        print("expression tree\n")
        print(b)
        return b
    
    elif p:
        print('Using p =', p)
        eps = 1E-5
    
        grad_norm = sqrt(InnerProduct(grad(X), grad(X)) + eps**2)
        

        c = BilinearForm(VEC)
        c += (grad_norm**(p-2)) * InnerProduct(grad(X), grad(PHI)) * dx
        c += InnerProduct(X,PHI)*dx
        
        # -DJ(Omega)(PHI)
        c += -InnerProduct((div(PHI)*(grad(gfu)- grad_ud)), grad(gfu)- grad_ud) * dx
        c += 2* InnerProduct(grad(gfu)- grad_ud, hesse(ud)*PHI) * dx
        c += -div(PHI)* gfu *gfp *dx
        c += -InnerProduct(div(PHI)*grad(gfu), grad(gfp)) * dx
        c += InnerProduct(PHI.Deriv()*grad(gfu), grad(gfp)) * dx
        c += InnerProduct(grad(gfu), PHI.Deriv()*grad(gfp)) * dx
        c += div(PHI)* f * gfp * dx
        c += grad_f*PHI*gfp * dx
        
        return c

        
    print("expression tree\n")
    print(b)
    return b
   

# def SolveNewton(printrates=True):
#     for ir in range(10):
#         if printrates: 
#             print("Newton step ", ir)
#         res = gfX.vec.CreateVector()
#         c.Apply(gfX.vec, res)
#         #print(res)     
#         res.data -= dJOmega.vec 
        
#         c.AssembleLinearization(gfX.vec)
#         # print(type(c.mat))
#         # plt.spy(c.mat.ToDense())
#         gfX.vec.data -= c.mat.Inverse(VEC.FreeDofs()) * res

def SolveDeformationEquation(linear=True):
    if linear:
        print("solving linear deformation equation")
        rhs = gfX.vec.CreateVector()
        rhs.data = dJOmega.vec - b.mat * gfX.vec
        update = gfX.vec.CreateVector()
        update.data = b.mat.Inverse(VEC.FreeDofs()) * rhs
        gfX.vec.data += update
        #scene_gfset.Redraw()
   
    elif not linear:
        print("solving nonlinear deformation equation with Newton")
        Newton(c, gfX, maxerr = 1E-8, freedofs=VEC.FreeDofs(), maxit = 1000, printing=True)

        #print("Deformation norm:", Norm(gfX.vec)
        #scene_gfset.Redraw()

# %%
def optimize_shape(linear = True):
    gfset.Set((0,0))
    mesh.SetDeformation(gfset)
    scene.Redraw()
    a.Assemble()
    fstate.Assemble()
    SolveStateEquation()

    LineSearch = True

    iter_max = 1000
    Jold = Integrate(Cost(gfu), mesh)
    converged = False

    # input("Press enter to start optimization")
    print('Cost at initial design', Integrate (Cost(gfu), mesh))
    for k in range(iter_max):
        mesh.SetDeformation(gfset)
        scene.Redraw()

        print('cost at iteration', k, ': ', Jold)

        a.Assemble()
        fstate.Assemble()
        SolveStateEquation()

        fadjoint.Assemble()
        SolveAdjointEquation()
        if linear:
            b.Assemble()
        #plt.spy(b.mat.ToDense())
        dJOmega.Assemble()
        SolveDeformationEquation(linear=linear)

        scale = 0.01 / Norm(gfX.vec)
        gfsetOld = gfset
        gfset.vec.data -= scale * gfX.vec

        Jnew = Integrate(Cost(gfu), mesh)

        if LineSearch:
            while Jnew > Jold and scale > 1e-12:
                #input('a')
                scale = scale / 2
                print("scale = ", scale)
                #print("scale without normalization factor = ", scale* Norm(gfX.vec))
                if scale <= 1e-12:
                    converged = True
                    break

                gfset.vec.data = gfsetOld.vec - scale * gfX.vec         # scale times -X is descent direction
                mesh.SetDeformation(gfset)                              # applying deformation and solve new state

                a.Assemble()                                           # note that during line search we only have to solve state to check if update yields lower costs              
                fstate.Assemble()
                SolveStateEquation()
                Jnew = Integrate(Cost(gfu), mesh)
                print("New cost during line search: ", Jnew)
        
        print("Optimality condition", np.dot(dJOmega.vec.FV().NumPy(), gfX.vec.FV().NumPy()))

        if converged==True:
            print("No more descent can be found")
            break
        Jold = Jnew

        Redraw(blocking=True)

    print("Norm of gset", Integrate(gfset**2, mesh))

# %% [markdown]
# ### linear

# %%
check_mesh_quality(mesh)
gfX = GridFunction(VEC)
#scene_gfset = Draw(gfX, mesh)
#gfX.Set((x *(1-x)*y*(1-y),0)) 
b = pose_deformation_equation()
#b.Assemble()


# gfset denotes the deformation of the original domain and will be updated during the shape optimization
gfset = GridFunction(VEC)
gfset.Set((0,0))

scene = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)



optimize_shape(linear = True)
print("Mesh quality after optimization (min, max): ")
mesh.SetDeformation(gfset)
check_mesh_quality(mesh, gfSet=gfset)

# gfX2 = GridFunction(VEC)
# gfX2.vec.data =
# print("=====")
# print(np.dot(dJOmega.vec.FV().NumPy(), gfX.vec.FV().NumPy()))
# print(Integrate(Cost(gfu), mesh))
# Out:
# Mesh quality metrics (min, max, mean, median): 1.004671, 1.566507, 1.149765, 1.125579
# expression tree
#
# on space H1HighOrderFESpace(h1ho)
# symmetric   = 0
# multilevel  = 1
# nonassemble = 0
# printelmat = 0
# elmatev    = 0
# eliminate_internal = 0
# eliminate_hidden = 0
# keep_internal = 0
# store_inner = 0
# integrators:
#   Symbolic BFI
#   Symbolic BFI
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# Cost at initial design 248080.62354813796
# cost at iteration 0 :  248080.62354813796
# solving linear deformation equation
# Optimality condition 320097544362.0567
# cost at iteration 1 :  246432.6052887279
# solving linear deformation equation
# Optimality condition 317033901121.71063
# cost at iteration 2 :  244886.70890078286
# solving linear deformation equation
# Optimality condition 313995469888.3557
# cost at iteration 3 :  243347.47711589537
# solving linear deformation equation
# Optimality condition 310982094594.0916
# cost at iteration 4 :  241814.90235169456
# solving linear deformation equation
# Optimality condition 307993619819.53
# cost at iteration 5 :  240288.9770339856
# solving linear deformation equation
# Optimality condition 305029890792.021
# cost at iteration 6 :  238769.69359596504
# solving linear deformation equation
# Optimality condition 302090753383.919
# cost at iteration 7 :  237257.04447745095
# solving linear deformation equation
# Optimality condition 299176054110.8615
# cost at iteration 8 :  235751.0221241009
# solving linear deformation equation
# Optimality condition 296285640130.087
# cost at iteration 9 :  234251.61898664295
# solving linear deformation equation
# Optimality condition 293419359238.77014
# cost at iteration 10 :  232758.82752010564
# solving linear deformation equation
# Optimality condition 290577059872.3821
# cost at iteration 11 :  231272.64018304524
# solving linear deformation equation
# Optimality condition 287758591103.0879
# cost at iteration 12 :  229793.04943678624
# solving linear deformation equation
# Optimality condition 284963802638.1473
# cost at iteration 13 :  228320.0477446521
# solving linear deformation equation
# Optimality condition 282192544818.3672
# cost at iteration 14 :  226853.62757121286
# solving linear deformation equation
# Optimality condition 279444668616.55646
# cost at iteration 15 :  225393.78138152615
# solving linear deformation equation
# Optimality condition 276720025636.0175
# cost at iteration 16 :  223940.50164038566
# solving linear deformation equation
# Optimality condition 274018468109.05994
# cost at iteration 17 :  222493.7808115744
# solving linear deformation equation
# Optimality condition 271339848895.53445
# cost at iteration 18 :  221053.61135712286
# solving linear deformation equation
# Optimality condition 268684021481.3947
# cost at iteration 19 :  219619.9857365663
# solving linear deformation equation
# Optimality condition 266050839977.28098
# cost at iteration 20 :  218192.89640621605
# solving linear deformation equation
# Optimality condition 263440159117.1278
# cost at iteration 21 :  216772.33581842875
# solving linear deformation equation
# Optimality condition 260851834256.79382
# cost at iteration 22 :  215358.29642088205
# solving linear deformation equation
# Optimality condition 258285721372.7144
# cost at iteration 23 :  213950.77065586016
# solving linear deformation equation
# Optimality condition 255741677060.5753
# cost at iteration 24 :  212549.75095953865
# solving linear deformation equation
# Optimality condition 253219558534.01337
# cost at iteration 25 :  211155.22976128192
# solving linear deformation equation
# Optimality condition 250719223623.3321
# cost at iteration 26 :  209767.19948294415
# solving linear deformation equation
# Optimality condition 248240530774.2437
# cost at iteration 27 :  208385.65253817567
# solving linear deformation equation
# Optimality condition 245783339046.6309
# cost at iteration 28 :  207010.581331737
# solving linear deformation equation
# Optimality condition 243347508113.32968
# cost at iteration 29 :  205641.97825882398
# solving linear deformation equation
# Optimality condition 240932898258.93027
# cost at iteration 30 :  204279.8357043958
# solving linear deformation equation
# Optimality condition 238539370378.60126
# cost at iteration 31 :  202924.14604250906
# solving linear deformation equation
# Optimality condition 236166785976.93405
# cost at iteration 32 :  201574.9016356686
# solving linear deformation equation
# Optimality condition 233815007166.80157
# cost at iteration 33 :  200232.09483417525
# solving linear deformation equation
# Optimality condition 231483896668.24594
# cost at iteration 34 :  198895.71797549212
# solving linear deformation equation
# Optimality condition 229173317807.37082
# cost at iteration 35 :  197565.7633836114
# solving linear deformation equation
# Optimality condition 226883134515.26678
# cost at iteration 36 :  196242.22336843822
# solving linear deformation equation
# Optimality condition 224613211326.94366
# cost at iteration 37 :  194925.0902251745
# solving linear deformation equation
# Optimality condition 222363413380.28674
# cost at iteration 38 :  193614.35623372032
# solving linear deformation equation
# Optimality condition 220133606415.03027
# cost at iteration 39 :  192310.01365808144
# solving linear deformation equation
# Optimality condition 217923656771.73978
# cost at iteration 40 :  191012.05474578557
# solving linear deformation equation
# Optimality condition 215733431390.82492
# cost at iteration 41 :  189720.4717273123
# solving linear deformation equation
# Optimality condition 213562797811.5548
# cost at iteration 42 :  188435.25681552995
# solving linear deformation equation
# Optimality condition 211411624171.0975
# cost at iteration 43 :  187156.40220514472
# solving linear deformation equation
# Optimality condition 209279779203.57208
# cost at iteration 44 :  185883.9000721612
# solving linear deformation equation
# Optimality condition 207167132239.11487
# cost at iteration 45 :  184617.74257335142
# solving linear deformation equation
# Optimality condition 205073553202.9614
# cost at iteration 46 :  183357.92184573927
# solving linear deformation equation
# Optimality condition 202998912614.54224
# cost at iteration 47 :  182104.43000609137
# solving linear deformation equation
# Optimality condition 200943081586.59344
# cost at iteration 48 :  180857.25915042273
# solving linear deformation equation
# Optimality condition 198905931824.27667
# cost at iteration 49 :  179616.40135351586
# solving linear deformation equation
# Optimality condition 196887335624.31714
# cost at iteration 50 :  178381.8486684459
# solving linear deformation equation
# Optimality condition 194887165874.1512
# cost at iteration 51 :  177153.59312612447
# solving linear deformation equation
# Optimality condition 192905296051.08444
# cost at iteration 52 :  175931.62673485136
# solving linear deformation equation
# Optimality condition 190941600221.4675
# cost at iteration 53 :  174715.94147988272
# solving linear deformation equation
# Optimality condition 188995953039.8731
# cost at iteration 54 :  173506.52932300555
# solving linear deformation equation
# Optimality condition 187068229748.29456
# cost at iteration 55 :  172303.3822021341
# solving linear deformation equation
# Optimality condition 185158306175.34622
# cost at iteration 56 :  171106.4920309118
# solving linear deformation equation
# Optimality condition 183266058735.48062
# cost at iteration 57 :  169915.8506983301
# solving linear deformation equation
# Optimality condition 181391364428.20636
# cost at iteration 58 :  168731.4500683562
# solving linear deformation equation
# Optimality condition 179534100837.32553
# cost at iteration 59 :  167553.28197958288
# solving linear deformation equation
# Optimality condition 177694146130.17065
# cost at iteration 60 :  166381.33824488198
# solving linear deformation equation
# Optimality condition 175871379056.85663
# cost at iteration 61 :  165215.61065107846
# solving linear deformation equation
# Optimality condition 174065678949.53308
# cost at iteration 62 :  164056.09095863486
# solving linear deformation equation
# Optimality condition 172276925721.65253
# cost at iteration 63 :  162902.77090135062
# solving linear deformation equation
# Optimality condition 170504999867.23688
# cost at iteration 64 :  161755.64218607536
# solving linear deformation equation
# Optimality condition 168749782460.15982
# cost at iteration 65 :  160614.69649243995
# solving linear deformation equation
# Optimality condition 167011155153.42236
# cost at iteration 66 :  159479.92547258892
# solving linear deformation equation
# Optimality condition 165289000178.4486
# cost at iteration 67 :  158351.3207509468
# solving linear deformation equation
# Optimality condition 163583200344.37576
# cost at iteration 68 :  157228.87392398136
# solving linear deformation equation
# Optimality condition 161893639037.35062
# cost at iteration 69 :  156112.57655998954
# solving linear deformation equation
# Optimality condition 160220200219.83737
# cost at iteration 70 :  155002.42019889882
# solving linear deformation equation
# Optimality condition 158562768429.91907
# cost at iteration 71 :  153898.39635207568
# solving linear deformation equation
# Optimality condition 156921228780.61072
# cost at iteration 72 :  152800.49650215692
# solving linear deformation equation
# Optimality condition 155295466959.17056
# cost at iteration 73 :  151708.71210289013
# solving linear deformation equation
# Optimality condition 153685369226.41632
# cost at iteration 74 :  150623.0345789916
# solving linear deformation equation
# Optimality condition 152090822416.0416
# cost at iteration 75 :  149543.45532601498
# solving linear deformation equation
# Optimality condition 150511713933.93726
# cost at iteration 76 :  148469.96571023812
# solving linear deformation equation
# Optimality condition 148947931757.50998
# cost at iteration 77 :  147402.5570685638
# solving linear deformation equation
# Optimality condition 147399364435.0067
# cost at iteration 78 :  146341.22070843342
# solving linear deformation equation
# Optimality condition 145865901084.83545
# cost at iteration 79 :  145285.94790775387
# solving linear deformation equation
# Optimality condition 144347431394.8871
# cost at iteration 80 :  144236.7299148448
# solving linear deformation equation
# Optimality condition 142843845621.85934
# cost at iteration 81 :  143193.55794839063
# solving linear deformation equation
# Optimality condition 141355034590.5775
# cost at iteration 82 :  142156.42319741618
# solving linear deformation equation
# Optimality condition 139880889693.31738
# cost at iteration 83 :  141125.31682127182
# solving linear deformation equation
# Optimality condition 138421302889.12177
# cost at iteration 84 :  140100.2299496315
# solving linear deformation equation
# Optimality condition 136976166703.12106
# cost at iteration 85 :  139081.15368250865
# solving linear deformation equation
# Optimality condition 135545374225.84682
# cost at iteration 86 :  138068.07909028025
# solving linear deformation equation
# Optimality condition 134128819112.54672
# cost at iteration 87 :  137060.99721373286
# solving linear deformation equation
# Optimality condition 132726395582.49615
# cost at iteration 88 :  136059.8990641157
# solving linear deformation equation
# Optimality condition 131337998418.3031
# cost at iteration 89 :  135064.7756232067
# solving linear deformation equation
# Optimality condition 129963522965.21426
# cost at iteration 90 :  134075.61784339772
# solving linear deformation equation
# Optimality condition 128602865130.41612
# cost at iteration 91 :  133092.4166477898
# solving linear deformation equation
# Optimality condition 127255921382.32785
# cost at iteration 92 :  132115.16293029598
# solving linear deformation equation
# Optimality condition 125922588749.89853
# cost at iteration 93 :  131143.84755577068
# solving linear deformation equation
# Optimality condition 124602764821.88936
# cost at iteration 94 :  130178.46136013581
# solving linear deformation equation
# Optimality condition 123296347746.15901
# cost at iteration 95 :  129218.9951505314
# solving linear deformation equation
# Optimality condition 122003236228.93857
# cost at iteration 96 :  128265.43970547232
# solving linear deformation equation
# Optimality condition 120723329534.10374
# cost at iteration 97 :  127317.78577501842
# solving linear deformation equation
# Optimality condition 119456527482.44032
# cost at iteration 98 :  126376.02408095858
# solving linear deformation equation
# Optimality condition 118202730450.90353
# cost at iteration 99 :  125440.14531700507
# solving linear deformation equation
# Optimality condition 116961839371.8679
# cost at iteration 100 :  124510.14014899435
# solving linear deformation equation
# Optimality condition 115733755732.3775
# cost at iteration 101 :  123585.9992151113
# solving linear deformation equation
# Optimality condition 114518381573.38046
# cost at iteration 102 :  122667.71312610914
# solving linear deformation equation
# Optimality condition 113315619488.96426
# cost at iteration 103 :  121755.2724655529
# solving linear deformation equation
# Optimality condition 112125372625.57654
# cost at iteration 104 :  120848.66779006453
# solving linear deformation equation
# Optimality condition 110947544681.24307
# cost at iteration 105 :  119947.88962958314
# solving linear deformation equation
# Optimality condition 109782039904.77498
# cost at iteration 106 :  119052.92848763076
# solving linear deformation equation
# Optimality condition 108628763094.97083
# cost at iteration 107 :  118163.7748415953
# solving linear deformation equation
# Optimality condition 107487619599.8035
# cost at iteration 108 :  117280.41914300881
# solving linear deformation equation
# Optimality condition 106358515315.60783
# cost at iteration 109 :  116402.85181784976
# solving linear deformation equation
# Optimality condition 105241356686.25049
# cost at iteration 110 :  115531.06326684356
# solving linear deformation equation
# Optimality condition 104136050702.29672
# cost at iteration 111 :  114665.04386577584
# solving linear deformation equation
# Optimality condition 103042504900.16307
# cost at iteration 112 :  113804.78396580875
# solving linear deformation equation
# Optimality condition 101960627361.2655
# cost at iteration 113 :  112950.27389381279
# solving linear deformation equation
# Optimality condition 100890326711.15283
# cost at iteration 114 :  112101.50395269474
# solving linear deformation equation
# Optimality condition 99831512118.6332
# cost at iteration 115 :  111258.46442174171
# solving linear deformation equation
# Optimality condition 98784093294.88773
# cost at iteration 116 :  110421.14555696526
# solving linear deformation equation
# Optimality condition 97747980492.57759
# cost at iteration 117 :  109589.53759145267
# solving linear deformation equation
# Optimality condition 96723084504.93625
# cost at iteration 118 :  108763.63073572682
# solving linear deformation equation
# Optimality condition 95709316664.85364
# cost at iteration 119 :  107943.41517810366
# solving linear deformation equation
# Optimality condition 94706588843.94759
# cost at iteration 120 :  107128.88108506141
# solving linear deformation equation
# Optimality condition 93714813451.62425
# cost at iteration 121 :  106320.01860160733
# solving linear deformation equation
# Optimality condition 92733903434.12833
# cost at iteration 122 :  105516.81785165357
# solving linear deformation equation
# Optimality condition 91763772273.58037
# cost at iteration 123 :  104719.26893839017
# solving linear deformation equation
# Optimality condition 90804333987.00186
# cost at iteration 124 :  103927.36194466456
# solving linear deformation equation
# Optimality condition 89855503125.32953
# cost at iteration 125 :  103141.08693336108
# solving linear deformation equation
# Optimality condition 88917194772.41605
# cost at iteration 126 :  102360.43394778024
# solving linear deformation equation
# Optimality condition 87989324544.01825
# cost at iteration 127 :  101585.39301202136
# solving linear deformation equation
# Optimality condition 87071808586.7749
# cost at iteration 128 :  100815.95413136444
# solving linear deformation equation
# Optimality condition 86164563577.16669
# cost at iteration 129 :  100052.10729264811
# solving linear deformation equation
# Optimality condition 85267506720.46848
# cost at iteration 130 :  99293.84246465193
# solving linear deformation equation
# Optimality condition 84380555749.68321
# cost at iteration 131 :  98541.14959847064
# solving linear deformation equation
# Optimality condition 83503628924.46617
# cost at iteration 132 :  97794.01862789279
# solving linear deformation equation
# Optimality condition 82636645030.03275
# cost at iteration 133 :  97052.43946976878
# solving linear deformation equation
# Optimality condition 81779523376.0516
# cost at iteration 134 :  96316.4020243797
# solving linear deformation equation
# Optimality condition 80932183795.52603
# cost at iteration 135 :  95585.89617580075
# solving linear deformation equation
# Optimality condition 80094546643.65689
# cost at iteration 136 :  94860.91179225684
# solving linear deformation equation
# Optimality condition 79266532796.69366
# cost at iteration 137 :  94141.43872647586
# solving linear deformation equation
# Optimality condition 78448063650.7678
# cost at iteration 138 :  93427.46681603038
# solving linear deformation equation
# Optimality condition 77639061120.7109
# cost at iteration 139 :  92718.98588367448
# solving linear deformation equation
# Optimality condition 76839447638.85814
# cost at iteration 140 :  92015.98573767197
# solving linear deformation equation
# Optimality condition 76049146153.83176
# cost at iteration 141 :  91318.45617211185
# solving linear deformation equation
# Optimality condition 75268080129.31255
# cost at iteration 142 :  90626.38696721727
# solving linear deformation equation
# Optimality condition 74496173542.7883
# cost at iteration 143 :  89939.76788963831
# solving linear deformation equation
# Optimality condition 73733350884.29057
# cost at iteration 144 :  89258.58869273821
# solving linear deformation equation
# Optimality condition 72979537155.10756
# cost at iteration 145 :  88582.83911685892
# solving linear deformation equation
# Optimality condition 72234657866.48236
# cost at iteration 146 :  87912.5088895777
# solving linear deformation equation
# Optimality condition 71498639038.29004
# cost at iteration 147 :  87247.58772594367
# solving linear deformation equation
# Optimality condition 70771407197.69537
# cost at iteration 148 :  86588.0653287023
# solving linear deformation equation
# Optimality condition 70052889377.79176
# cost at iteration 149 :  85933.93138849718
# solving linear deformation equation
# Optimality condition 69343013116.21602
# cost at iteration 150 :  85285.17558405297
# solving linear deformation equation
# Optimality condition 68641706453.74484
# cost at iteration 151 :  84641.78758234058
# solving linear deformation equation
# Optimality condition 67948897932.86776
# cost at iteration 152 :  84003.75703871725
# solving linear deformation equation
# Optimality condition 67264516596.33693
# cost at iteration 153 :  83371.07359704512
# solving linear deformation equation
# Optimality condition 66588491985.69437
# cost at iteration 154 :  82743.72688978277
# solving linear deformation equation
# Optimality condition 65920754139.7746
# cost at iteration 155 :  82121.7065380542
# solving linear deformation equation
# Optimality condition 65261233593.18059
# cost at iteration 156 :  81505.00215168379
# solving linear deformation equation
# Optimality condition 64609861374.73628
# cost at iteration 157 :  80893.60332920802
# solving linear deformation equation
# Optimality condition 63966569005.90968
# cost at iteration 158 :  80287.49965784965
# solving linear deformation equation
# Optimality condition 63331288499.21068
# cost at iteration 159 :  79686.68071346631
# solving linear deformation equation
# Optimality condition 62703952356.55734
# cost at iteration 160 :  79091.13606045413
# solving linear deformation equation
# Optimality condition 62084493567.614815
# cost at iteration 161 :  78500.85525162508
# solving linear deformation equation
# Optimality condition 61472845608.10078
# cost at iteration 162 :  77915.82782803575
# solving linear deformation equation
# Optimality condition 60868942438.06096
# cost at iteration 163 :  77336.04331878219
# solving linear deformation equation
# Optimality condition 60272718500.11072
# cost at iteration 164 :  76761.49124074857
# solving linear deformation equation
# Optimality condition 59684108717.64107
# cost at iteration 165 :  76192.16109830953
# solving linear deformation equation
# Optimality condition 59103048492.9893
# cost at iteration 166 :  75628.0423829847
# solving linear deformation equation
# Optimality condition 58529473705.573006
# cost at iteration 167 :  75069.12457304548
# solving linear deformation equation
# Optimality condition 57963320709.98517
# cost at iteration 168 :  74515.39713306756
# solving linear deformation equation
# Optimality condition 57404526334.04692
# cost at iteration 169 :  73966.84951342293
# solving linear deformation equation
# Optimality condition 56853027876.82233
# cost at iteration 170 :  73423.4711497244
# solving linear deformation equation
# Optimality condition 56308763106.58525
# cost at iteration 171 :  72885.25146219517
# solving linear deformation equation
# Optimality condition 55771670258.744774
# cost at iteration 172 :  72352.1798549868
# solving linear deformation equation
# Optimality condition 55241688033.721146
# cost at iteration 173 :  71824.24571542059
# solving linear deformation equation
# Optimality condition 54718755594.77309
# cost at iteration 174 :  71301.4384131621
# solving linear deformation equation
# Optimality condition 54202812565.77602
# cost at iteration 175 :  70783.74729932281
# solving linear deformation equation
# Optimality condition 53693799028.94372
# cost at iteration 176 :  70271.16170547812
# solving linear deformation equation
# Optimality condition 53191655522.4995
# cost at iteration 177 :  69763.67094261236
# solving linear deformation equation
# Optimality condition 52696323038.28555
# cost at iteration 178 :  69261.264299972
# solving linear deformation equation
# Optimality condition 52207743019.31669
# cost at iteration 179 :  68763.9310438334
# solving linear deformation equation
# Optimality condition 51725857357.26868
# cost at iteration 180 :  68271.66041617368
# solving linear deformation equation
# Optimality condition 51250608389.9055
# cost at iteration 181 :  67784.44163325126
# solving linear deformation equation
# Optimality condition 50781938898.436264
# cost at iteration 182 :  67302.26388407529
# solving linear deformation equation
# Optimality condition 50319792104.80466
# cost at iteration 183 :  66825.11632877485
# solving linear deformation equation
# Optimality condition 49864111668.907036
# cost at iteration 184 :  66352.98809685813
# solving linear deformation equation
# Optimality condition 49414841685.73207
# cost at iteration 185 :  65885.86828535123
# solving linear deformation equation
# Optimality condition 48971926682.42554
# cost at iteration 186 :  65423.74595681903
# solving linear deformation equation
# Optimality condition 48535311615.27254
# cost at iteration 187 :  64966.61013725954
# solving linear deformation equation
# Optimality condition 48104941866.59571
# cost at iteration 188 :  64514.44981386709
# solving linear deformation equation
# Optimality condition 47680763241.56762
# cost at iteration 189 :  64067.25393265992
# solving linear deformation equation
# Optimality condition 47262721964.93055
# cost at iteration 190 :  63625.011395963
# solving linear deformation equation
# Optimality condition 46850764677.6246
# cost at iteration 191 :  63187.71105974599
# solving linear deformation equation
# Optimality condition 46444838433.31746
# cost at iteration 192 :  62755.34173080531
# solving linear deformation equation
# Optimality condition 46044890694.83406
# cost at iteration 193 :  62327.89216378748
# solving linear deformation equation
# Optimality condition 45650869330.482544
# cost at iteration 194 :  61905.35105804674
# solving linear deformation equation
# Optimality condition 45262722610.27216
# cost at iteration 195 :  61487.70705433032
# solving linear deformation equation
# Optimality condition 44880399202.0203
# cost at iteration 196 :  61074.94873128634
# solving linear deformation equation
# Optimality condition 44503848167.34444
# cost at iteration 197 :  60667.06460178514
# solving linear deformation equation
# Optimality condition 44133018957.53558
# cost at iteration 198 :  60264.043109050996
# solving linear deformation equation
# Optimality condition 43767861409.310394
# cost at iteration 199 :  59865.87262259802
# solving linear deformation equation
# Optimality condition 43408325740.43576
# cost at iteration 200 :  59472.54143395778
# solving linear deformation equation
# Optimality condition 43054362545.22493
# cost at iteration 201 :  59084.03775219918
# solving linear deformation equation
# Optimality condition 42705922789.900314
# cost at iteration 202 :  58700.34969923134
# solving linear deformation equation
# Optimality condition 42362957807.81804
# cost at iteration 203 :  58321.46530488019
# solving linear deformation equation
# Optimality condition 42025419294.553986
# cost at iteration 204 :  57947.37250174023
# solving linear deformation equation
# Optimality condition 41693259302.843094
# cost at iteration 205 :  57578.059119782745
# solving linear deformation equation
# Optimality condition 41366430237.37272
# cost at iteration 206 :  57213.51288072626
# solving linear deformation equation
# Optimality condition 41044884849.424416
# cost at iteration 207 :  56853.721392158666
# solving linear deformation equation
# Optimality condition 40728576231.362015
# cost at iteration 208 :  56498.67214140364
# solving linear deformation equation
# Optimality condition 40417457810.95959
# cost at iteration 209 :  56148.35248912314
# solving linear deformation equation
# Optimality condition 40111483345.57409
# cost at iteration 210 :  55802.749662665214
# solving linear deformation equation
# Optimality condition 39810606916.149
# cost at iteration 211 :  55461.85074912816
# solving linear deformation equation
# Optimality condition 39514782921.057816
# cost at iteration 212 :  55125.642688163025
# solving linear deformation equation
# Optimality condition 39223966069.77663
# cost at iteration 213 :  54794.112264490446
# solving linear deformation equation
# Optimality condition 38938111376.38789
# cost at iteration 214 :  54467.24610013516
# solving linear deformation equation
# Optimality condition 38657174152.91435
# cost at iteration 215 :  54145.030646383144
# solving linear deformation equation
# Optimality condition 38381110002.47853
# cost at iteration 216 :  53827.45217544245
# solving linear deformation equation
# Optimality condition 38109874812.29194
# cost at iteration 217 :  53514.49677182448
# solving linear deformation equation
# Optimality condition 37843424746.46915
# cost at iteration 218 :  53206.15032343239
# solving linear deformation equation
# Optimality condition 37581716238.67058
# cost at iteration 219 :  52902.3985123643
# solving linear deformation equation
# Optimality condition 37324705984.57215
# cost at iteration 220 :  52603.2268054276
# solving linear deformation equation
# Optimality condition 37072350934.16598
# cost at iteration 221 :  52308.62044437298
# solving linear deformation equation
# Optimality condition 36824608283.89171
# cost at iteration 222 :  52018.56443584628
# solving linear deformation equation
# Optimality condition 36581435468.60318
# cost at iteration 223 :  51733.04354106732
# solving linear deformation equation
# Optimality condition 36342790153.3734
# cost at iteration 224 :  51452.04226524016
# solving linear deformation equation
# Optimality condition 36108630225.14295
# cost at iteration 225 :  51175.54484670558
# solving linear deformation equation
# Optimality condition 35878913784.21586
# cost at iteration 226 :  50903.53524584058
# solving linear deformation equation
# Optimality condition 35653599135.61078
# cost at iteration 227 :  50635.997133721066
# solving linear deformation equation
# Optimality condition 35432644780.27553
# cost at iteration 228 :  50372.91388056317
# solving linear deformation equation
# Optimality condition 35216009406.16965
# cost at iteration 229 :  50114.26854394659
# solving linear deformation equation
# Optimality condition 35003651879.22989
# cost at iteration 230 :  49860.043856854325
# solving linear deformation equation
# Optimality condition 34795531234.224884
# cost at iteration 231 :  49610.2222155323
# solving linear deformation equation
# Optimality condition 34591606665.513756
# cost at iteration 232 :  49364.78566720225
# solving linear deformation equation
# Optimality condition 34391837517.719666
# cost at iteration 233 :  49123.71589764241
# solving linear deformation equation
# Optimality condition 34196183276.335747
# cost at iteration 234 :  48886.99421867153
# solving linear deformation equation
# Optimality condition 34004603558.276268
# cost at iteration 235 :  48654.60155555625
# solving linear deformation equation
# Optimality condition 33817058102.391518
# cost at iteration 236 :  48426.51843437629
# solving linear deformation equation
# Optimality condition 33633506759.966156
# cost at iteration 237 :  48202.72496938472
# solving linear deformation equation
# Optimality condition 33453909485.219154
# cost at iteration 238 :  47983.20085039135
# solving linear deformation equation
# Optimality condition 33278226325.828297
# cost at iteration 239 :  47767.9253302165
# solving linear deformation equation
# Optimality condition 33106417413.50058
# cost at iteration 240 :  47556.87721224648
# solving linear deformation equation
# Optimality condition 32938442954.61529
# cost at iteration 241 :  47350.03483814554
# solving linear deformation equation
# Optimality condition 32774263220.963478
# cost at iteration 242 :  47147.37607576091
# solving linear deformation equation
# Optimality condition 32613838540.610493
# cost at iteration 243 :  46948.878307271756
# solving linear deformation equation
# Optimality condition 32457129288.912193
# cost at iteration 244 :  46754.51841763471
# solving linear deformation equation
# Optimality condition 32304095879.71249
# cost at iteration 245 :  46564.27278337651
# solving linear deformation equation
# Optimality condition 32154698756.7546
# cost at iteration 246 :  46378.1172617884
# solving linear deformation equation
# Optimality condition 32008898385.33514
# cost at iteration 247 :  46196.027180577046
# solving linear deformation equation
# Optimality condition 31866655244.237778
# cost at iteration 248 :  46017.977328031935
# solving linear deformation equation
# Optimality condition 31727929817.976185
# cost at iteration 249 :  45843.941943765734
# solving linear deformation equation
# Optimality condition 31592682589.383892
# cost at iteration 250 :  45673.89471008919
# solving linear deformation equation
# Optimality condition 31460874032.5831
# cost at iteration 251 :  45507.808744078764
# solving linear deformation equation
# Optimality condition 31332464606.369915
# cost at iteration 252 :  45345.65659040032
# solving linear deformation equation
# Optimality condition 31207414748.04926
# cost at iteration 253 :  45187.41021494374
# solving linear deformation equation
# Optimality condition 31085684867.757202
# cost at iteration 254 :  45033.04099933895
# solving linear deformation equation
# Optimality condition 30967235343.302185
# cost at iteration 255 :  44882.51973639709
# solving linear deformation equation
# Optimality condition 30852026515.563747
# cost at iteration 256 :  44735.81662655174
# solving linear deformation equation
# Optimality condition 30740018684.478516
# cost at iteration 257 :  44592.90127534051
# solving linear deformation equation
# Optimality condition 30631172105.648758
# cost at iteration 258 :  44453.742691992644
# solving linear deformation equation
# Optimality condition 30525446987.603138
# cost at iteration 259 :  44318.30928916439
# solving linear deformation equation
# Optimality condition 30422803489.739502
# cost at iteration 260 :  44186.56888387427
# solving linear deformation equation
# Optimality condition 30323201720.979515
# cost at iteration 261 :  44058.48869968496
# solving linear deformation equation
# Optimality condition 30226601739.156384
# cost at iteration 262 :  43934.035370160775
# solving linear deformation equation
# Optimality condition 30132963551.1643
# cost at iteration 263 :  43813.17494365032
# solving linear deformation equation
# Optimality condition 30042247113.883934
# cost at iteration 264 :  43695.87288940755
# solving linear deformation equation
# Optimality condition 29954412335.907738
# cost at iteration 265 :  43582.09410509149
# solving linear deformation equation
# Optimality condition 29869419080.073402
# cost at iteration 266 :  43471.80292564951
# solving linear deformation equation
# Optimality condition 29787227166.820694
# cost at iteration 267 :  43364.963133606565
# solving linear deformation equation
# Optimality condition 29707796378.375656
# cost at iteration 268 :  43261.53797075709
# solving linear deformation equation
# Optimality condition 29631086463.76628
# cost at iteration 269 :  43161.490151261125
# solving linear deformation equation
# Optimality condition 29557057144.66947
# cost at iteration 270 :  43064.781876139765
# solving linear deformation equation
# Optimality condition 29485668122.08288
# cost at iteration 271 :  42971.37484914774
# solving linear deformation equation
# Optimality condition 29416879083.812885
# cost at iteration 272 :  42881.230294002184
# solving linear deformation equation
# Optimality condition 29350649712.765053
# cost at iteration 273 :  42794.30897294054
# solving linear deformation equation
# Optimality condition 29286939696.017776
# cost at iteration 274 :  42710.571206561144
# solving linear deformation equation
# Optimality condition 29225708734.657944
# cost at iteration 275 :  42629.976894908825
# solving linear deformation equation
# Optimality condition 29166916554.351288
# cost at iteration 276 :  42552.485539752575
# solving linear deformation equation
# Optimality condition 29110522916.615803
# cost at iteration 277 :  42478.05626799133
# solving linear deformation equation
# Optimality condition 29056487630.762863
# cost at iteration 278 :  42406.64785612583
# solving linear deformation equation
# Optimality condition 29004770566.468353
# cost at iteration 279 :  42338.21875572664
# solving linear deformation equation
# Optimality condition 28955331666.928894
# cost at iteration 280 :  42272.727119817006
# solving linear deformation equation
# Optimality condition 28908130962.557835
# cost at iteration 281 :  42210.130830089816
# solving linear deformation equation
# Optimality condition 28863128585.17234
# cost at iteration 282 :  42150.38752487719
# solving linear deformation equation
# Optimality condition 28820284782.616978
# cost at iteration 283 :  42093.454627770734
# solving linear deformation equation
# Optimality condition 28779559933.770664
# cost at iteration 284 :  42039.2893768091
# solving linear deformation equation
# Optimality condition 28740914563.87879
# cost at iteration 285 :  41987.848854128395
# solving linear deformation equation
# Optimality condition 28704309360.152557
# cost at iteration 286 :  41939.09001598193
# solving linear deformation equation
# Optimality condition 28669705187.57528
# cost at iteration 287 :  41892.969723028495
# solving linear deformation equation
# Optimality condition 28637063104.852688
# cost at iteration 288 :  41849.44477078198
# solving linear deformation equation
# Optimality condition 28606344380.448486
# cost at iteration 289 :  41808.47192013094
# solving linear deformation equation
# Optimality condition 28577510508.641224
# cost at iteration 290 :  41770.00792782333
# solving linear deformation equation
# Optimality condition 28550523225.542137
# cost at iteration 291 :  41734.009576817814
# solving linear deformation equation
# Optimality condition 28525344525.01287
# cost at iteration 292 :  41700.433706405776
# solving linear deformation equation
# Optimality condition 28501936674.424072
# cost at iteration 293 :  41669.23724201352
# solving linear deformation equation
# Optimality condition 28480262230.19773
# cost at iteration 294 :  41640.377224591146
# solving linear deformation equation
# Optimality condition 28460284053.07438
# cost at iteration 295 :  41613.81083949941
# solving linear deformation equation
# Optimality condition 28441965323.056305
# cost at iteration 296 :  41589.49544482186
# solving linear deformation equation
# Optimality condition 28425269553.970825
# cost at iteration 297 :  41567.388599011305
# solving linear deformation equation
# Optimality condition 28410160607.609787
# cost at iteration 298 :  41547.44808781339
# solving linear deformation equation
# Optimality condition 28396602707.395615
# cost at iteration 299 :  41529.63195038259
# solving linear deformation equation
# Optimality condition 28384560451.537548
# cost at iteration 300 :  41513.89850454978
# solving linear deformation equation
# Optimality condition 28373998825.635605
# cost at iteration 301 :  41500.20637116958
# solving linear deformation equation
# Optimality condition 28364883214.698723
# cost at iteration 302 :  41488.5144975018
# solving linear deformation equation
# Optimality condition 28357179414.547672
# cost at iteration 303 :  41478.78217959
# solving linear deformation equation
# Optimality condition 28350853642.57578
# cost at iteration 304 :  41470.969083595555
# solving linear deformation equation
# Optimality condition 28345872547.840725
# cost at iteration 305 :  41465.03526604959
# solving linear deformation equation
# Optimality condition 28342203220.474274
# cost at iteration 306 :  41460.94119301122
# solving linear deformation equation
# Optimality condition 28339813200.3891
# cost at iteration 307 :  41458.64775810016
# solving linear deformation equation
# Optimality condition 28338670485.274162
# cost at iteration 308 :  41458.11629939556
# solving linear deformation equation
# scale =  1.3065606576796454e-08
# New cost during line search:  40929.276558525955
# Optimality condition 28338743537.8691
# cost at iteration 309 :  40929.276558525955
# solving linear deformation equation
# scale =  1.3104567166937293e-08
# New cost during line search:  40931.066945493454
# scale =  6.5522835834686465e-09
# New cost during line search:  40931.45341412847
# scale =  3.2761417917343233e-09
# New cost during line search:  40931.656088764204
# scale =  1.6380708958671616e-09
# New cost during line search:  40931.75978640363
# scale =  8.190354479335808e-10
# New cost during line search:  40931.81222533492
# scale =  4.095177239667904e-10
# New cost during line search:  40931.838592331675
# scale =  2.047588619833952e-10
# New cost during line search:  40931.85181271359
# scale =  1.023794309916976e-10
# New cost during line search:  40931.85843212521
# scale =  5.11897154958488e-11
# New cost during line search:  40931.86174413652
# scale =  2.55948577479244e-11
# New cost during line search:  40931.86340071839
# scale =  1.27974288739622e-11
# New cost during line search:  40931.86422915345
# scale =  6.3987144369811e-12
# New cost during line search:  40931.8646434068
# scale =  3.19935721849055e-12
# New cost during line search:  40931.86485054236
# scale =  1.599678609245275e-12
# New cost during line search:  40931.86495411269
# scale =  7.998393046226375e-13
# Optimality condition 28340733713.782227
# No more descent can be found
# Norm of gset 0.07745998476576804
# Mesh quality after optimization (min, max):
# Error processing element <ngsolve.comp.Ngs_Element object at 0x11dea8330>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x11dea8fb0>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x11dea43f0>: Meshpoint 1 not in mesh!
# Mesh quality metrics (min, max, mean, median): 1.007475, 34.629918, 1.989333, 1.372651
# Warning: 172 elements with poor quality (>2)

# %% [markdown]
# ### non linear with p

# %%
check_mesh_quality(mesh)
b = pose_deformation_equation(p=3)

gfX = GridFunction(VEC)
#scene_gfset = Draw(gfX, mesh)
# gfset denotes the deformation of the original domain and will be updated during the shape optimization
gfset = GridFunction(VEC)

gfset.Set((0,0))
scene = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)

optimize_shape(linear=True)
check_mesh_quality(mesh, gfSet=gfset)
# Out:
# Mesh quality metrics (min, max, mean, median): 1.004671, 1.566507, 1.149765, 1.125579
# Using p = 3
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# Cost at initial design 248080.6235481377
# cost at iteration 0 :  248080.6235481377
# solving linear deformation equation
# Optimality condition 320097544349.62067
# cost at iteration 1 :  246432.6052887316
# solving linear deformation equation
# Optimality condition 317033901109.3932
# cost at iteration 2 :  244886.70890079014
# solving linear deformation equation
# Optimality condition 313995469876.15466
# cost at iteration 3 :  243347.4771159062
# solving linear deformation equation
# Optimality condition 310982094582.0066
# cost at iteration 4 :  241814.9023517095
# solving linear deformation equation
# Optimality condition 307993619807.55994
# cost at iteration 5 :  240288.97703400473
# solving linear deformation equation
# Optimality condition 305029890780.16516
# cost at iteration 6 :  238769.6935959879
# solving linear deformation equation
# Optimality condition 302090753372.17505
# cost at iteration 7 :  237257.04447747627
# solving linear deformation equation
# Optimality condition 299176054099.2311
# cost at iteration 8 :  235751.02212413037
# solving linear deformation equation
# Optimality condition 296285640118.5672
# cost at iteration 9 :  234251.6189866756
# solving linear deformation equation
# Optimality condition 293419359227.3601
# cost at iteration 10 :  232758.8275201412
# solving linear deformation equation
# Optimality condition 290577059861.08246
# cost at iteration 11 :  231272.64018308473
# solving linear deformation equation
# Optimality condition 287758591091.8955
# cost at iteration 12 :  229793.0494368278
# solving linear deformation equation
# Optimality condition 284963802627.0624
# cost at iteration 13 :  228320.0477446968
# solving linear deformation equation
# Optimality condition 282192544807.3885
# cost at iteration 14 :  226853.62757126
# solving linear deformation equation
# Optimality condition 279444668605.68286
# cost at iteration 15 :  225393.78138157615
# solving linear deformation equation
# Optimality condition 276720025625.24817
# cost at iteration 16 :  223940.50164043793
# solving linear deformation equation
# Optimality condition 274018468098.39465
# cost at iteration 17 :  222493.78081162955
# solving linear deformation equation
# Optimality condition 271339848884.97202
# cost at iteration 18 :  221053.61135718037
# solving linear deformation equation
# Optimality condition 268684021470.93414
# cost at iteration 19 :  219619.9857366264
# solving linear deformation equation
# Optimality condition 266050839966.92093
# cost at iteration 20 :  218192.89640627854
# solving linear deformation equation
# Optimality condition 263440159106.8684
# cost at iteration 21 :  216772.33581849386
# solving linear deformation equation
# Optimality condition 260851834246.6344
# cost at iteration 22 :  215358.29642095
# solving linear deformation equation
# Optimality condition 258285721362.6524
# cost at iteration 23 :  213950.77065592966
# solving linear deformation equation
# Optimality condition 255741677050.61053
# cost at iteration 24 :  212549.7509596102
# solving linear deformation equation
# Optimality condition 253219558524.14517
# cost at iteration 25 :  211155.22976135576
# solving linear deformation equation
# Optimality condition 250719223613.5592
# cost at iteration 26 :  209767.1994830199
# solving linear deformation equation
# Optimality condition 248240530764.56567
# cost at iteration 27 :  208385.65253825235
# solving linear deformation equation
# Optimality condition 245783339037.04697
# cost at iteration 28 :  207010.5813318159
# solving linear deformation equation
# Optimality condition 243347508103.839
# cost at iteration 29 :  205641.9782589053
# solving linear deformation equation
# Optimality condition 240932898249.53143
# cost at iteration 30 :  204279.83570447835
# solving linear deformation equation
# Optimality condition 238539370369.29385
# cost at iteration 31 :  202924.1460425931
# solving linear deformation equation
# Optimality condition 236166785967.71677
# cost at iteration 32 :  201574.90163575357
# solving linear deformation equation
# Optimality condition 233815007157.6756
# cost at iteration 33 :  200232.09483426216
# solving linear deformation equation
# Optimality condition 231483896659.2089
# cost at iteration 34 :  198895.71797558063
# solving linear deformation equation
# Optimality condition 229173317798.4225
# cost at iteration 35 :  197565.76338370208
# solving linear deformation equation
# Optimality condition 226883134506.4052
# cost at iteration 36 :  196242.2233685295
# solving linear deformation equation
# Optimality condition 224613211318.16864
# cost at iteration 37 :  194925.0902252669
# solving linear deformation equation
# Optimality condition 222363413371.5985
# cost at iteration 38 :  193614.3562338146
# solving linear deformation equation
# Optimality condition 220133606406.4267
# cost at iteration 39 :  192310.01365817676
# solving linear deformation equation
# Optimality condition 217923656763.22046
# cost at iteration 40 :  191012.0547458822
# solving linear deformation equation
# Optimality condition 215733431382.38892
# cost at iteration 41 :  189720.47172740946
# solving linear deformation equation
# Optimality condition 213562797803.20148
# cost at iteration 42 :  188435.25681562815
# solving linear deformation equation
# Optimality condition 211411624162.8263
# cost at iteration 43 :  187156.40220524394
# solving linear deformation equation
# Optimality condition 209279779195.38254
# cost at iteration 44 :  185883.9000722617
# solving linear deformation equation
# Optimality condition 207167132231.006
# cost at iteration 45 :  184617.7425734528
# solving linear deformation equation
# Optimality condition 205073553194.93222
# cost at iteration 46 :  183357.92184584096
# solving linear deformation equation
# Optimality condition 202998912606.5927
# cost at iteration 47 :  182104.43000619428
# solving linear deformation equation
# Optimality condition 200943081578.72147
# cost at iteration 48 :  180857.25915052654
# solving linear deformation equation
# Optimality condition 198905931816.48233
# cost at iteration 49 :  179616.4013536203
# solving linear deformation equation
# Optimality condition 196887335616.60016
# cost at iteration 50 :  178381.84866855128
# solving linear deformation equation
# Optimality condition 194887165866.51013
# cost at iteration 51 :  177153.5931262304
# solving linear deformation equation
# Optimality condition 192905296043.5188
# cost at iteration 52 :  175931.6267349576
# solving linear deformation equation
# Optimality condition 190941600213.97632
# cost at iteration 53 :  174715.94147998866
# solving linear deformation equation
# Optimality condition 188995953032.4558
# cost at iteration 54 :  173506.52932311178
# solving linear deformation equation
# Optimality condition 187068229740.95087
# cost at iteration 55 :  172303.38220224157
# solving linear deformation equation
# Optimality condition 185158306168.0762
# cost at iteration 56 :  171106.4920310207
# solving linear deformation equation
# Optimality condition 183266058728.28186
# cost at iteration 57 :  169915.8506984382
# solving linear deformation equation
# Optimality condition 181391364421.0791
# cost at iteration 58 :  168731.45006846535
# solving linear deformation equation
# Optimality condition 179534100830.26892
# cost at iteration 59 :  167553.2819796925
# solving linear deformation equation
# Optimality condition 177694146123.18423
# cost at iteration 60 :  166381.33824499152
# solving linear deformation equation
# Optimality condition 175871379049.93915
# cost at iteration 61 :  165215.61065118818
# solving linear deformation equation
# Optimality condition 174065678942.68405
# cost at iteration 62 :  164056.09095874446
# solving linear deformation equation
# Optimality condition 172276925714.87146
# cost at iteration 63 :  162902.77090146064
# solving linear deformation equation
# Optimality condition 170504999860.52356
# cost at iteration 64 :  161755.6421861862
# solving linear deformation equation
# Optimality condition 168749782453.51266
# cost at iteration 65 :  160614.69649254967
# solving linear deformation equation
# Optimality condition 167011155146.8416
# cost at iteration 66 :  159479.92547269957
# solving linear deformation equation
# Optimality condition 165289000171.9336
# cost at iteration 67 :  158351.32075105747
# solving linear deformation equation
# Optimality condition 163583200337.92502
# cost at iteration 68 :  157228.8739240916
# solving linear deformation equation
# Optimality condition 161893639030.96396
# cost at iteration 69 :  156112.5765601
# solving linear deformation equation
# Optimality condition 160220200213.51428
# cost at iteration 70 :  155002.4201990093
# solving linear deformation equation
# Optimality condition 158562768423.65924
# cost at iteration 71 :  153898.3963521862
# solving linear deformation equation
# Optimality condition 156921228774.4131
# cost at iteration 72 :  152800.49650226714
# solving linear deformation equation
# Optimality condition 155295466953.03455
# cost at iteration 73 :  151708.71210300064
# solving linear deformation equation
# Optimality condition 153685369220.34122
# cost at iteration 74 :  150623.0345791017
# solving linear deformation equation
# Optimality condition 152090822410.02692
# cost at iteration 75 :  149543.45532612424
# solving linear deformation equation
# Optimality condition 150511713927.9823
# cost at iteration 76 :  148469.9657103478
# solving linear deformation equation
# Optimality condition 148947931751.61462
# cost at iteration 77 :  147402.55706867337
# solving linear deformation equation
# Optimality condition 147399364429.17023
# cost at iteration 78 :  146341.22070854256
# solving linear deformation equation
# Optimality condition 145865901079.05685
# cost at iteration 79 :  145285.94790786286
# solving linear deformation equation
# Optimality condition 144347431389.16574
# cost at iteration 80 :  144236.72991495326
# solving linear deformation equation
# Optimality condition 142843845616.19464
# cost at iteration 81 :  143193.55794849875
# solving linear deformation equation
# Optimality condition 141355034584.96967
# cost at iteration 82 :  142156.42319752407
# solving linear deformation equation
# Optimality condition 139880889687.76544
# cost at iteration 83 :  141125.31682137935
# solving linear deformation equation
# Optimality condition 138421302883.62518
# cost at iteration 84 :  140100.22994973866
# solving linear deformation equation
# Optimality condition 136976166697.67897
# cost at iteration 85 :  139081.15368261497
# solving linear deformation equation
# Optimality condition 135545374220.45879
# cost at iteration 86 :  138068.07909038628
# solving linear deformation equation
# Optimality condition 134128819107.21214
# cost at iteration 87 :  137060.9972138388
# solving linear deformation equation
# Optimality condition 132726395577.21495
# cost at iteration 88 :  136059.8990642212
# solving linear deformation equation
# Optimality condition 131337998413.07442
# cost at iteration 89 :  135064.77562331158
# solving linear deformation equation
# Optimality condition 129963522960.03777
# cost at iteration 90 :  134075.61784350264
# solving linear deformation equation
# Optimality condition 128602865125.29062
# cost at iteration 91 :  133092.41664789364
# solving linear deformation equation
# Optimality condition 127255921377.25366
# cost at iteration 92 :  132115.16293039973
# solving linear deformation equation
# Optimality condition 125922588744.87448
# cost at iteration 93 :  131143.84755587374
# solving linear deformation equation
# Optimality condition 124602764816.91548
# cost at iteration 94 :  130178.46136023857
# solving linear deformation equation
# Optimality condition 123296347741.2337
# cost at iteration 95 :  129218.99515063303
# solving linear deformation equation
# Optimality condition 122003236224.062
# cost at iteration 96 :  128265.43970557312
# solving linear deformation equation
# Optimality condition 120723329529.27591
# cost at iteration 97 :  127317.78577511896
# solving linear deformation equation
# Optimality condition 119456527477.66045
# cost at iteration 98 :  126376.02408105877
# solving linear deformation equation
# Optimality condition 118202730446.17075
# cost at iteration 99 :  125440.14531710367
# solving linear deformation equation
# Optimality condition 116961839367.18234
# cost at iteration 100 :  124510.14014909347
# solving linear deformation equation
# Optimality condition 115733755727.73773
# cost at iteration 101 :  123585.9992152089
# solving linear deformation equation
# Optimality condition 114518381568.78677
# cost at iteration 102 :  122667.71312620635
# solving linear deformation equation
# Optimality condition 113315619484.41577
# cost at iteration 103 :  121755.27246564944
# solving linear deformation equation
# Optimality condition 112125372621.07281
# cost at iteration 104 :  120848.66779016012
# solving linear deformation equation
# Optimality condition 110947544676.78377
# cost at iteration 105 :  119947.88962967801
# solving linear deformation equation
# Optimality condition 109782039900.35968
# cost at iteration 106 :  119052.92848772538
# solving linear deformation equation
# Optimality condition 108628763090.59875
# cost at iteration 107 :  118163.77484168863
# solving linear deformation equation
# Optimality condition 107487619595.47444
# cost at iteration 108 :  117280.41914310098
# solving linear deformation equation
# Optimality condition 106358515311.32117
# cost at iteration 109 :  116402.85181794122
# solving linear deformation equation
# Optimality condition 105241356682.00581
# cost at iteration 110 :  115531.06326693422
# solving linear deformation equation
# Optimality condition 104136050698.09349
# cost at iteration 111 :  114665.04386586529
# solving linear deformation equation
# Optimality condition 103042504896.0011
# cost at iteration 112 :  113804.78396589785
# solving linear deformation equation
# Optimality condition 101960627357.14433
# cost at iteration 113 :  112950.27389390115
# solving linear deformation equation
# Optimality condition 100890326707.07193
# cost at iteration 114 :  112101.50395278221
# solving linear deformation equation
# Optimality condition 99831512114.5916
# cost at iteration 115 :  111258.4644218279
# solving linear deformation equation
# Optimality condition 98784093290.88585
# cost at iteration 116 :  110421.14555705081
# solving linear deformation equation
# Optimality condition 97747980488.61464
# cost at iteration 117 :  109589.5375915378
# solving linear deformation equation
# Optimality condition 96723084501.0119
# cost at iteration 118 :  108763.63073581079
# solving linear deformation equation
# Optimality condition 95709316660.96707
# cost at iteration 119 :  107943.41517818658
# solving linear deformation equation
# Optimality condition 94706588840.09846
# cost at iteration 120 :  107128.88108514316
# solving linear deformation equation
# Optimality condition 93714813447.81238
# cost at iteration 121 :  106320.01860168845
# solving linear deformation equation
# Optimality condition 92733903430.3534
# cost at iteration 122 :  105516.81785173372
# solving linear deformation equation
# Optimality condition 91763772269.84149
# cost at iteration 123 :  104719.26893846907
# solving linear deformation equation
# Optimality condition 90804333983.29913
# cost at iteration 124 :  103927.36194474252
# solving linear deformation equation
# Optimality condition 89855503121.66222
# cost at iteration 125 :  103141.08693343804
# solving linear deformation equation
# Optimality condition 88917194768.78374
# cost at iteration 126 :  102360.43394785594
# solving linear deformation equation
# Optimality condition 87989324540.42104
# cost at iteration 127 :  101585.39301209661
# solving linear deformation equation
# Optimality condition 87071808583.21198
# cost at iteration 128 :  100815.95413143864
# solving linear deformation equation
# Optimality condition 86164563573.63742
# cost at iteration 129 :  100052.10729272064
# solving linear deformation equation
# Optimality condition 85267506716.97235
# cost at iteration 130 :  99293.842464723
# solving linear deformation equation
# Optimality condition 84380555746.22049
# cost at iteration 131 :  98541.1495985413
# solving linear deformation equation
# Optimality condition 83503628921.03639
# cost at iteration 132 :  97794.01862796272
# solving linear deformation equation
# Optimality condition 82636645026.63504
# cost at iteration 133 :  97052.43946983722
# solving linear deformation equation
# Optimality condition 81779523372.686
# cost at iteration 134 :  96316.40202444688
# solving linear deformation equation
# Optimality condition 80932183792.19193
# cost at iteration 135 :  95585.89617586709
# solving linear deformation equation
# Optimality condition 80094546640.35423
# cost at iteration 136 :  94860.91179232241
# solving linear deformation equation
# Optimality condition 79266532793.42181
# cost at iteration 137 :  94141.43872654004
# solving linear deformation equation
# Optimality condition 78448063647.52634
# cost at iteration 138 :  93427.46681609312
# solving linear deformation equation
# Optimality condition 77639061117.49977
# cost at iteration 139 :  92718.98588373659
# solving linear deformation equation
# Optimality condition 76839447635.67657
# cost at iteration 140 :  92015.98573773286
# solving linear deformation equation
# Optimality condition 76049146150.67976
# cost at iteration 141 :  91318.45617217159
# solving linear deformation equation
# Optimality condition 75268080126.18933
# cost at iteration 142 :  90626.38696727554
# solving linear deformation equation
# Optimality condition 74496173539.6939
# cost at iteration 143 :  89939.76788969563
# solving linear deformation equation
# Optimality condition 73733350881.22449
# cost at iteration 144 :  89258.58869279419
# solving linear deformation equation
# Optimality condition 72979537152.06964
# cost at iteration 145 :  88582.83911691401
# solving linear deformation equation
# Optimality condition 72234657863.4718
# cost at iteration 146 :  87912.50888963089
# solving linear deformation equation
# Optimality condition 71498639035.307
# cost at iteration 147 :  87247.58772599633
# solving linear deformation equation
# Optimality condition 70771407194.73938
# cost at iteration 148 :  86588.06532875377
# solving linear deformation equation
# Optimality condition 70052889374.86243
# cost at iteration 149 :  85933.93138854756
# solving linear deformation equation
# Optimality condition 69343013113.3129
# cost at iteration 150 :  85285.17558410215
# solving linear deformation equation
# Optimality condition 68641706450.86751
# cost at iteration 151 :  84641.78758238819
# solving linear deformation equation
# Optimality condition 67948897930.01581
# cost at iteration 152 :  84003.7570387632
# solving linear deformation equation
# Optimality condition 67264516593.51041
# cost at iteration 153 :  83371.07359708968
# solving linear deformation equation
# Optimality condition 66588491982.89301
# cost at iteration 154 :  82743.72688982659
# solving linear deformation equation
# Optimality condition 65920754136.99802
# cost at iteration 155 :  82121.70653809684
# solving linear deformation equation
# Optimality condition 65261233590.42818
# cost at iteration 156 :  81505.002151725
# solving linear deformation equation
# Optimality condition 64609861372.00766
# cost at iteration 157 :  80893.60332924762
# solving linear deformation equation
# Optimality condition 63966569003.205154
# cost at iteration 158 :  80287.4996578886
# solving linear deformation equation
# Optimality condition 63331288496.52939
# cost at iteration 159 :  79686.68071350359
# solving linear deformation equation
# Optimality condition 62703952353.89929
# cost at iteration 160 :  79091.13606049027
# solving linear deformation equation
# Optimality condition 62084493564.979614
# cost at iteration 161 :  78500.85525165993
# solving linear deformation equation
# Optimality condition 61472845605.487816
# cost at iteration 162 :  77915.82782806894
# solving linear deformation equation
# Optimality condition 60868942435.47041
# cost at iteration 163 :  77336.04331881442
# solving linear deformation equation
# Optimality condition 60272718497.5421
# cost at iteration 164 :  76761.49124077945
# solving linear deformation equation
# Optimality condition 59684108715.09398
# cost at iteration 165 :  76192.16109833859
# solving linear deformation equation
# Optimality condition 59103048490.46358
# cost at iteration 166 :  75628.04238301278
# solving linear deformation equation
# Optimality condition 58529473703.0683
# cost at iteration 167 :  75069.12457307205
# solving linear deformation equation
# Optimality condition 57963320707.50105
# cost at iteration 168 :  74515.39713309257
# solving linear deformation equation
# Optimality condition 57404526331.58328
# cost at iteration 169 :  73966.84951344666
# solving linear deformation equation
# Optimality condition 56853027874.37869
# cost at iteration 170 :  73423.47114974642
# solving linear deformation equation
# Optimality condition 56308763104.16153
# cost at iteration 171 :  72885.25146221594
# solving linear deformation equation
# Optimality condition 55771670256.34073
# cost at iteration 172 :  72352.17985500615
# solving linear deformation equation
# Optimality condition 55241688031.33656
# cost at iteration 173 :  71824.24571543864
# solving linear deformation equation
# Optimality condition 54718755592.40774
# cost at iteration 174 :  71301.43841317944
# solving linear deformation equation
# Optimality condition 54202812563.42928
# cost at iteration 175 :  70783.74729933807
# solving linear deformation equation
# Optimality condition 53693799026.61551
# cost at iteration 176 :  70271.16170549166
# solving linear deformation equation
# Optimality condition 53191655520.18948
# cost at iteration 177 :  69763.67094262455
# solving linear deformation equation
# Optimality condition 52696323035.99345
# cost at iteration 178 :  69261.26429998274
# solving linear deformation equation
# Optimality condition 52207743017.04231
# cost at iteration 179 :  68763.93104384228
# solving linear deformation equation
# Optimality condition 51725857355.0121
# cost at iteration 180 :  68271.66041618206
# solving linear deformation equation
# Optimality condition 51250608387.665985
# cost at iteration 181 :  67784.44163325785
# solving linear deformation equation
# Optimality condition 50781938896.21366
# cost at iteration 182 :  67302.26388408021
# solving linear deformation equation
# Optimality condition 50319792102.598854
# cost at iteration 183 :  66825.11632877817
# solving linear deformation equation
# Optimality condition 49864111666.71773
# cost at iteration 184 :  66352.98809686018
# solving linear deformation equation
# Optimality condition 49414841683.55903
# cost at iteration 185 :  65885.86828535193
# solving linear deformation equation
# Optimality condition 48971926680.26837
# cost at iteration 186 :  65423.74595681802
# solving linear deformation equation
# Optimality condition 48535311613.13103
# cost at iteration 187 :  64966.61013725697
# solving linear deformation equation
# Optimality condition 48104941864.46976
# cost at iteration 188 :  64514.449813863095
# solving linear deformation equation
# Optimality condition 47680763239.45692
# cost at iteration 189 :  64067.25393265452
# solving linear deformation equation
# Optimality condition 47262721962.834915
# cost at iteration 190 :  63625.011395956084
# solving linear deformation equation
# Optimality condition 46850764675.54378
# cost at iteration 191 :  63187.711059737674
# solving linear deformation equation
# Optimality condition 46444838431.2512
# cost at iteration 192 :  62755.34173079542
# solving linear deformation equation
# Optimality condition 46044890692.78195
# cost at iteration 193 :  62327.89216377575
# solving linear deformation equation
# Optimality condition 45650869328.44444
# cost at iteration 194 :  61905.351058033135
# solving linear deformation equation
# Optimality condition 45262722608.24808
# cost at iteration 195 :  61487.70705431569
# solving linear deformation equation
# Optimality condition 44880399200.00985
# cost at iteration 196 :  61074.94873127017
# solving linear deformation equation
# Optimality condition 44503848165.34737
# cost at iteration 197 :  60667.064601767066
# solving linear deformation equation
# Optimality condition 44133018955.55162
# cost at iteration 198 :  60264.04310903132
# solving linear deformation equation
# Optimality condition 43767861407.339424
# cost at iteration 199 :  59865.87262257698
# solving linear deformation equation
# Optimality condition 43408325738.47751
# cost at iteration 200 :  59472.541433935134
# solving linear deformation equation
# Optimality condition 43054362543.279205
# cost at iteration 201 :  59084.03775217475
# solving linear deformation equation
# Optimality condition 42705922787.96676
# cost at iteration 202 :  58700.349699205035
# solving linear deformation equation
# Optimality condition 42362957805.896774
# cost at iteration 203 :  58321.4653048528
# solving linear deformation equation
# Optimality condition 42025419292.6446
# cost at iteration 204 :  57947.37250171113
# solving linear deformation equation
# Optimality condition 41693259300.94534
# cost at iteration 205 :  57578.059119751706
# solving linear deformation equation
# Optimality condition 41366430235.48641
# cost at iteration 206 :  57213.51288069365
# solving linear deformation equation
# Optimality condition 41044884847.54958
# cost at iteration 207 :  56853.721392124935
# solving linear deformation equation
# Optimality condition 40728576229.498146
# cost at iteration 208 :  56498.672141368064
# solving linear deformation equation
# Optimality condition 40417457809.10675
# cost at iteration 209 :  56148.35248908626
# solving linear deformation equation
# Optimality condition 40111483343.73163
# cost at iteration 210 :  55802.74966262602
# solving linear deformation equation
# Optimality condition 39810606914.31702
# cost at iteration 211 :  55461.85074908727
# solving linear deformation equation
# Optimality condition 39514782919.23636
# cost at iteration 212 :  55125.64268812118
# solving linear deformation equation
# Optimality condition 39223966067.965096
# cost at iteration 213 :  54794.112264446405
# solving linear deformation equation
# Optimality condition 38938111374.58644
# cost at iteration 214 :  54467.24610009017
# solving linear deformation equation
# Optimality condition 38657174151.12245
# cost at iteration 215 :  54145.03064633609
# solving linear deformation equation
# Optimality condition 38381110000.69628
# cost at iteration 216 :  53827.45217539404
# solving linear deformation equation
# Optimality condition 38109874810.518906
# cost at iteration 217 :  53514.49677177405
# solving linear deformation equation
# Optimality condition 37843424744.70524
# cost at iteration 218 :  53206.15032338049
# solving linear deformation equation
# Optimality condition 37581716236.915665
# cost at iteration 219 :  52902.39851231089
# solving linear deformation equation
# Optimality condition 37324705982.82611
# cost at iteration 220 :  52603.22680537258
# solving linear deformation equation
# Optimality condition 37072350932.42856
# cost at iteration 221 :  52308.620444316395
# solving linear deformation equation
# Optimality condition 36824608282.16269
# cost at iteration 222 :  52018.56443578786
# solving linear deformation equation
# Optimality condition 36581435466.88222
# cost at iteration 223 :  51733.04354100672
# solving linear deformation equation
# Optimality condition 36342790151.66071
# cost at iteration 224 :  51452.042265178556
# solving linear deformation equation
# Optimality condition 36108630223.4381
# cost at iteration 225 :  51175.54484664221
# solving linear deformation equation
# Optimality condition 35878913782.51865
# cost at iteration 226 :  50903.535245775194
# solving linear deformation equation
# Optimality condition 35653599133.92117
# cost at iteration 227 :  50635.99713365438
# solving linear deformation equation
# Optimality condition 35432644778.59321
# cost at iteration 228 :  50372.913880494394
# solving linear deformation equation
# Optimality condition 35216009404.494736
# cost at iteration 229 :  50114.268543876766
# solving linear deformation equation
# Optimality condition 35003651877.56198
# cost at iteration 230 :  49860.04385678266
# solving linear deformation equation
# Optimality condition 34795531232.56406
# cost at iteration 231 :  49610.22221545927
# solving linear deformation equation
# Optimality condition 34591606663.85947
# cost at iteration 232 :  49364.78566712704
# solving linear deformation equation
# Optimality condition 34391837516.07206
# cost at iteration 233 :  49123.71589756585
# solving linear deformation equation
# Optimality condition 34196183274.69455
# cost at iteration 234 :  48886.99421859334
# solving linear deformation equation
# Optimality condition 34004603556.64136
# cost at iteration 235 :  48654.60155547642
# solving linear deformation equation
# Optimality condition 33817058100.762802
# cost at iteration 236 :  48426.518434295125
# solving linear deformation equation
# Optimality condition 33633506758.34329
# cost at iteration 237 :  48202.72496930153
# solving linear deformation equation
# Optimality condition 33453909483.602173
# cost at iteration 238 :  47983.20085030684
# solving linear deformation equation
# Optimality condition 33278226324.216965
# cost at iteration 239 :  47767.9253301303
# solving linear deformation equation
# Optimality condition 33106417411.894665
# cost at iteration 240 :  47556.8772121585
# solving linear deformation equation
# Optimality condition 32938442953.014977
# cost at iteration 241 :  47350.03483805641
# solving linear deformation equation
# Optimality condition 32774263219.368347
# cost at iteration 242 :  47147.376075670196
# solving linear deformation equation
# Optimality condition 32613838539.020386
# cost at iteration 243 :  46948.87830717927
# solving linear deformation equation
# Optimality condition 32457129287.327034
# cost at iteration 244 :  46754.51841754072
# solving linear deformation equation
# Optimality condition 32304095878.132057
# cost at iteration 245 :  46564.272783280336
# solving linear deformation equation
# Optimality condition 32154698755.17881
# cost at iteration 246 :  46378.11726169093
# solving linear deformation equation
# Optimality condition 32008898383.763893
# cost at iteration 247 :  46196.02718047795
# solving linear deformation equation
# Optimality condition 31866655242.671005
# cost at iteration 248 :  46017.97732793161
# solving linear deformation equation
# Optimality condition 31727929816.413567
# cost at iteration 249 :  45843.9419436635
# solving linear deformation equation
# Optimality condition 31592682587.825417
# cost at iteration 250 :  45673.894709985405
# solving linear deformation equation
# Optimality condition 31460874031.02864
# cost at iteration 251 :  45507.808743973634
# solving linear deformation equation
# Optimality condition 31332464604.81936
# cost at iteration 252 :  45345.656590293605
# solving linear deformation equation
# Optimality condition 31207414746.502495
# cost at iteration 253 :  45187.41021483576
# solving linear deformation equation
# Optimality condition 31085684866.21398
# cost at iteration 254 :  45033.04099922918
# solving linear deformation equation
# Optimality condition 30967235341.762444
# cost at iteration 255 :  44882.51973628578
# solving linear deformation equation
# Optimality condition 30852026514.02738
# cost at iteration 256 :  44735.81662643879
# solving linear deformation equation
# Optimality condition 30740018682.94533
# cost at iteration 257 :  44592.90127522577
# solving linear deformation equation
# Optimality condition 30631172104.118805
# cost at iteration 258 :  44453.74269187685
# solving linear deformation equation
# Optimality condition 30525446986.076065
# cost at iteration 259 :  44318.309289046534
# solving linear deformation equation
# Optimality condition 30422803488.215443
# cost at iteration 260 :  44186.56888375544
# solving linear deformation equation
# Optimality condition 30323201719.45828
# cost at iteration 261 :  44058.48869956477
# solving linear deformation equation
# Optimality condition 30226601737.63791
# cost at iteration 262 :  43934.03537003939
# solving linear deformation equation
# Optimality condition 30132963549.648354
# cost at iteration 263 :  43813.17494352747
# solving linear deformation equation
# Optimality condition 30042247112.3705
# cost at iteration 264 :  43695.872889283244
# solving linear deformation equation
# Optimality condition 29954412334.396534
# cost at iteration 265 :  43582.09410496544
# solving linear deformation equation
# Optimality condition 29869419078.564445
# cost at iteration 266 :  43471.802925522075
# solving linear deformation equation
# Optimality condition 29787227165.31394
# cost at iteration 267 :  43364.96313347806
# solving linear deformation equation
# Optimality condition 29707796376.871017
# cost at iteration 268 :  43261.537970627214
# solving linear deformation equation
# Optimality condition 29631086462.26357
# cost at iteration 269 :  43161.490151129874
# solving linear deformation equation
# Optimality condition 29557057143.168472
# cost at iteration 270 :  43064.7818760068
# solving linear deformation equation
# Optimality condition 29485668120.583645
# cost at iteration 271 :  42971.374849013424
# solving linear deformation equation
# Optimality condition 29416879082.31535
# cost at iteration 272 :  42881.23029386662
# solving linear deformation equation
# Optimality condition 29350649711.26905
# cost at iteration 273 :  42794.308972803774
# solving linear deformation equation
# Optimality condition 29286939694.523224
# cost at iteration 274 :  42710.57120642292
# solving linear deformation equation
# Optimality condition 29225708733.164772
# cost at iteration 275 :  42629.9768947694
# solving linear deformation equation
# Optimality condition 29166916552.859436
# cost at iteration 276 :  42552.48553961192
# solving linear deformation equation
# Optimality condition 29110522915.12514
# cost at iteration 277 :  42478.05626784952
# solving linear deformation equation
# Optimality condition 29056487629.273422
# cost at iteration 278 :  42406.64785598316
# solving linear deformation equation
# Optimality condition 29004770564.97991
# cost at iteration 279 :  42338.218755582486
# solving linear deformation equation
# Optimality condition 28955331665.441254
# cost at iteration 280 :  42272.72711967107
# solving linear deformation equation
# Optimality condition 28908130961.07097
# cost at iteration 281 :  42210.13082994251
# solving linear deformation equation
# Optimality condition 28863128583.686455
# cost at iteration 282 :  42150.387524729194
# solving linear deformation equation
# Optimality condition 28820284781.131733
# cost at iteration 283 :  42093.45462762151
# solving linear deformation equation
# Optimality condition 28779559932.28605
# cost at iteration 284 :  42039.28937665855
# solving linear deformation equation
# Optimality condition 28740914562.39472
# cost at iteration 285 :  41987.848853976786
# solving linear deformation equation
# Optimality condition 28704309358.66897
# cost at iteration 286 :  41939.09001582903
# solving linear deformation equation
# Optimality condition 28669705186.092052
# cost at iteration 287 :  41892.96972287456
# solving linear deformation equation
# Optimality condition 28637063103.369843
# cost at iteration 288 :  41849.44477062685
# solving linear deformation equation
# Optimality condition 28606344378.96594
# cost at iteration 289 :  41808.47191997497
# solving linear deformation equation
# Optimality condition 28577510507.158985
# cost at iteration 290 :  41770.00792766679
# solving linear deformation equation
# Optimality condition 28550523224.05999
# cost at iteration 291 :  41734.00957665987
# solving linear deformation equation
# Optimality condition 28525344523.530624
# cost at iteration 292 :  41700.4337062465
# solving linear deformation equation
# Optimality condition 28501936672.94189
# cost at iteration 293 :  41669.23724185312
# solving linear deformation equation
# Optimality condition 28480262228.71528
# cost at iteration 294 :  41640.37722442917
# solving linear deformation equation
# Optimality condition 28460284051.591896
# cost at iteration 295 :  41613.810839336795
# solving linear deformation equation
# Optimality condition 28441965321.573555
# cost at iteration 296 :  41589.49544465797
# solving linear deformation equation
# Optimality condition 28425269552.4879
# cost at iteration 297 :  41567.388598846635
# solving linear deformation equation
# Optimality condition 28410160606.12652
# cost at iteration 298 :  41547.44808764746
# solving linear deformation equation
# Optimality condition 28396602705.911995
# cost at iteration 299 :  41529.631950215975
# solving linear deformation equation
# Optimality condition 28384560450.053627
# cost at iteration 300 :  41513.8985043825
# solving linear deformation equation
# Optimality condition 28373998824.151062
# cost at iteration 301 :  41500.20637100087
# solving linear deformation equation
# Optimality condition 28364883213.213554
# cost at iteration 302 :  41488.514497331846
# solving linear deformation equation
# Optimality condition 28357179413.06202
# cost at iteration 303 :  41478.78217941931
# solving linear deformation equation
# Optimality condition 28350853641.089237
# cost at iteration 304 :  41470.969083423006
# solving linear deformation equation
# Optimality condition 28345872546.35359
# cost at iteration 305 :  41465.035265876315
# solving linear deformation equation
# Optimality condition 28342203218.986557
# cost at iteration 306 :  41460.94119283773
# solving linear deformation equation
# Optimality condition 28339813198.90055
# cost at iteration 307 :  41458.64775792559
# solving linear deformation equation
# Optimality condition 28338670483.784767
# cost at iteration 308 :  41458.116299220004
# solving linear deformation equation
# scale =  1.306560657743075e-08
# New cost during line search:  40929.276558352314
# Optimality condition 28338743536.378807
# cost at iteration 309 :  40929.276558352314
# solving linear deformation equation
# scale =  1.3104567167574255e-08
# New cost during line search:  40931.06694531883
# scale =  6.552283583787128e-09
# New cost during line search:  40931.45341395321
# scale =  3.276141791893564e-09
# New cost during line search:  40931.65608858855
# scale =  1.638070895946782e-09
# New cost during line search:  40931.759786228205
# scale =  8.19035447973391e-10
# New cost during line search:  40931.81222515911
# scale =  4.095177239866955e-10
# New cost during line search:  40931.83859215681
# scale =  2.0475886199334774e-10
# New cost during line search:  40931.85181253796
# scale =  1.0237943099667387e-10
# New cost during line search:  40931.85843194994
# scale =  5.1189715498336934e-11
# New cost during line search:  40931.86174396106
# scale =  2.5594857749168467e-11
# New cost during line search:  40931.863400542854
# scale =  1.2797428874584234e-11
# New cost during line search:  40931.86422897751
# scale =  6.398714437292117e-12
# New cost during line search:  40931.86464323125
# scale =  3.1993572186460584e-12
# New cost during line search:  40931.86485036736
# scale =  1.5996786093230292e-12
# New cost during line search:  40931.86495393707
# scale =  7.998393046615146e-13
# Optimality condition 28340733712.29048
# No more descent can be found
# Norm of gset 0.07745998476570704
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112741f30>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112741630>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112741a70>: Meshpoint 1 not in mesh!
# Mesh quality metrics (min, max, mean, median): 1.007475, 34.629918, 1.989333, 1.372651
# Warning: 172 elements with poor quality (>2)

# %% [markdown]
# ### linear with gamma

# %%
check_mesh_quality(mesh)
b = pose_deformation_equation(gamma=100000)

gfX = GridFunction(VEC)
#scene_gfset = Draw(gfX, mesh)
# gfset denotes the deformation of the original domain and will be updated during the shape optimization
gfset = GridFunction(VEC)

gfset.Set((0,0))
scene = Draw(gfset,mesh,"gfset")
SetVisualization (deformation=True)

optimize_shape()
check_mesh_quality(mesh, gfSet=gfset)
# Out:
# Mesh quality metrics (min, max, mean, median): 1.004671, 1.566507, 1.149765, 1.125579
# Using gamma = 100000
# expression tree
#
# on space H1HighOrderFESpace(h1ho)
# symmetric   = 0
# multilevel  = 1
# nonassemble = 0
# printelmat = 0
# elmatev    = 0
# eliminate_internal = 0
# eliminate_hidden = 0
# keep_internal = 0
# store_inner = 0
# integrators:
#   Symbolic BFI
#   Symbolic BFI
#   Symbolic BFI
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.2…
# Cost at initial design 248080.62354813787
# cost at iteration 0 :  248080.62354813787
# solving linear deformation equation
# Optimality condition 3.200975443620569e+16
# cost at iteration 1 :  246432.6052887279
# solving linear deformation equation
# Optimality condition 3.1703390112171116e+16
# cost at iteration 2 :  244886.70890078312
# solving linear deformation equation
# Optimality condition 3.139954698883559e+16
# cost at iteration 3 :  243347.47711589534
# solving linear deformation equation
# Optimality condition 3.1098209459409172e+16
# cost at iteration 4 :  241814.9023516947
# solving linear deformation equation
# Optimality condition 3.0799361981952988e+16
# cost at iteration 5 :  240288.97703398543
# solving linear deformation equation
# Optimality condition 3.050298907920209e+16
# cost at iteration 6 :  238769.6935959652
# solving linear deformation equation
# Optimality condition 3.0209075338391836e+16
# cost at iteration 7 :  237257.04447745095
# solving linear deformation equation
# Optimality condition 2.9917605411086184e+16
# cost at iteration 8 :  235751.02212410106
# solving linear deformation equation
# Optimality condition 2.9628564013008668e+16
# cost at iteration 9 :  234251.61898664283
# solving linear deformation equation
# Optimality condition 2.9341935923876996e+16
# cost at iteration 10 :  232758.8275201057
# solving linear deformation equation
# Optimality condition 2.90577059872382e+16
# cost at iteration 11 :  231272.64018304506
# solving linear deformation equation
# Optimality condition 2.877585911030879e+16
# cost at iteration 12 :  229793.0494367865
# solving linear deformation equation
# Optimality condition 2.8496380263814764e+16
# cost at iteration 13 :  228320.04774465185
# solving linear deformation equation
# Optimality condition 2.821925448183669e+16
# cost at iteration 14 :  226853.62757121274
# solving linear deformation equation
# Optimality condition 2.79444668616556e+16
# cost at iteration 15 :  225393.7813815261
# solving linear deformation equation
# Optimality condition 2.7672002563601756e+16
# cost at iteration 16 :  223940.50164038566
# solving linear deformation equation
# Optimality condition 2.740184681090597e+16
# cost at iteration 17 :  222493.780811574
# solving linear deformation equation
# Optimality condition 2.7133984889553452e+16
# cost at iteration 18 :  221053.61135712234
# solving linear deformation equation
# Optimality condition 2.6868402148139424e+16
# cost at iteration 19 :  219619.98573656645
# solving linear deformation equation
# Optimality condition 2.660508399772811e+16
# cost at iteration 20 :  218192.89640621628
# solving linear deformation equation
# Optimality condition 2.634401591171281e+16
# cost at iteration 21 :  216772.33581842904
# solving linear deformation equation
# Optimality condition 2.608518342567938e+16
# cost at iteration 22 :  215358.29642088225
# solving linear deformation equation
# Optimality condition 2.582857213727139e+16
# cost at iteration 23 :  213950.7706558602
# solving linear deformation equation
# Optimality condition 2.557416770605756e+16
# cost at iteration 24 :  212549.750959539
# solving linear deformation equation
# Optimality condition 2.5321955853401296e+16
# cost at iteration 25 :  211155.2297612821
# solving linear deformation equation
# Optimality condition 2.507192236233316e+16
# cost at iteration 26 :  209767.19948294412
# solving linear deformation equation
# Optimality condition 2.482405307742438e+16
# cost at iteration 27 :  208385.65253817555
# solving linear deformation equation
# Optimality condition 2.4578333904663104e+16
# cost at iteration 28 :  207010.58133173684
# solving linear deformation equation
# Optimality condition 2.4334750811333e+16
# cost at iteration 29 :  205641.97825882403
# solving linear deformation equation
# Optimality condition 2.4093289825893e+16
# cost at iteration 30 :  204279.8357043957
# solving linear deformation equation
# Optimality condition 2.385393703786013e+16
# cost at iteration 31 :  202924.146042509
# solving linear deformation equation
# Optimality condition 2.3616678597693384e+16
# cost at iteration 32 :  201574.90163566847
# solving linear deformation equation
# Optimality condition 2.3381500716680188e+16
# cost at iteration 33 :  200232.09483417534
# solving linear deformation equation
# Optimality condition 2.3148389666824624e+16
# cost at iteration 34 :  198895.71797549207
# solving linear deformation equation
# Optimality condition 2.29173317807371e+16
# cost at iteration 35 :  197565.76338361148
# solving linear deformation equation
# Optimality condition 2.268831345152667e+16
# cost at iteration 36 :  196242.22336843816
# solving linear deformation equation
# Optimality condition 2.246132113269437e+16
# cost at iteration 37 :  194925.09022517462
# solving linear deformation equation
# Optimality condition 2.223634133802873e+16
# cost at iteration 38 :  193614.35623372035
# solving linear deformation equation
# Optimality condition 2.201336064150299e+16
# cost at iteration 39 :  192310.0136580816
# solving linear deformation equation
# Optimality condition 2.1792365677173944e+16
# cost at iteration 40 :  191012.05474578537
# solving linear deformation equation
# Optimality condition 2.1573343139082452e+16
# cost at iteration 41 :  189720.47172731205
# solving linear deformation equation
# Optimality condition 2.135627978115546e+16
# cost at iteration 42 :  188435.25681552978
# solving linear deformation equation
# Optimality condition 2.1141162417109744e+16
# cost at iteration 43 :  187156.4022051448
# solving linear deformation equation
# Optimality condition 2.0927977920357252e+16
# cost at iteration 44 :  185883.9000721611
# solving linear deformation equation
# Optimality condition 2.071671322391151e+16
# cost at iteration 45 :  184617.74257335157
# solving linear deformation equation
# Optimality condition 2.050735532029611e+16
# cost at iteration 46 :  183357.92184573915
# solving linear deformation equation
# Optimality condition 2.0299891261454252e+16
# cost at iteration 47 :  182104.43000609116
# solving linear deformation equation
# Optimality condition 2.0094308158659356e+16
# cost at iteration 48 :  180857.25915042314
# solving linear deformation equation
# Optimality condition 1.9890593182427644e+16
# cost at iteration 49 :  179616.40135351583
# solving linear deformation equation
# Optimality condition 1.9688733562431708e+16
# cost at iteration 50 :  178381.84866844615
# solving linear deformation equation
# Optimality condition 1.9488716587415092e+16
# cost at iteration 51 :  177153.593126124
# solving linear deformation equation
# Optimality condition 1.929052960510846e+16
# cost at iteration 52 :  175931.6267348513
# solving linear deformation equation
# Optimality condition 1.9094160022146736e+16
# cost at iteration 53 :  174715.94147988257
# solving linear deformation equation
# Optimality condition 1.8899595303987324e+16
# cost at iteration 54 :  173506.52932300544
# solving linear deformation equation
# Optimality condition 1.870682297482944e+16
# cost at iteration 55 :  172303.38220213391
# solving linear deformation equation
# Optimality condition 1.8515830617534636e+16
# cost at iteration 56 :  171106.49203091185
# solving linear deformation equation
# Optimality condition 1.832660587354805e+16
# cost at iteration 57 :  169915.85069832977
# solving linear deformation equation
# Optimality condition 1.8139136442820656e+16
# cost at iteration 58 :  168731.45006835597
# solving linear deformation equation
# Optimality condition 1.7953410083732556e+16
# cost at iteration 59 :  167553.28197958288
# solving linear deformation equation
# Optimality condition 1.7769414613017084e+16
# cost at iteration 60 :  166381.33824488195
# solving linear deformation equation
# Optimality condition 1.758713790568564e+16
# cost at iteration 61 :  165215.61065107843
# solving linear deformation equation
# Optimality condition 1.740656789495329e+16
# cost at iteration 62 :  164056.09095863462
# solving linear deformation equation
# Optimality condition 1.7227692572165196e+16
# cost at iteration 63 :  162902.7709013503
# solving linear deformation equation
# Optimality condition 1.70504999867237e+16
# cost at iteration 64 :  161755.64218607594
# solving linear deformation equation
# Optimality condition 1.6874978246015956e+16
# cost at iteration 65 :  160614.69649243975
# solving linear deformation equation
# Optimality condition 1.6701115515342266e+16
# cost at iteration 66 :  159479.92547258912
# solving linear deformation equation
# Optimality condition 1.6528900017844896e+16
# cost at iteration 67 :  158351.3207509469
# solving linear deformation equation
# Optimality condition 1.6358320034437556e+16
# cost at iteration 68 :  157228.87392398133
# solving linear deformation equation
# Optimality condition 1.6189363903735098e+16
# cost at iteration 69 :  156112.57655998954
# solving linear deformation equation
# Optimality condition 1.602202002198372e+16
# cost at iteration 70 :  155002.42019889876
# solving linear deformation equation
# Optimality condition 1.5856276842991892e+16
# cost at iteration 71 :  153898.3963520754
# solving linear deformation equation
# Optimality condition 1.5692122878061078e+16
# cost at iteration 72 :  152800.49650215713
# solving linear deformation equation
# Optimality condition 1.5529546695917054e+16
# cost at iteration 73 :  151708.71210289016
# solving linear deformation equation
# Optimality condition 1.5368536922641672e+16
# cost at iteration 74 :  150623.03457899194
# solving linear deformation equation
# Optimality condition 1.5209082241604178e+16
# cost at iteration 75 :  149543.45532601504
# solving linear deformation equation
# Optimality condition 1.5051171393393718e+16
# cost at iteration 76 :  148469.96571023815
# solving linear deformation equation
# Optimality condition 1.4894793175750984e+16
# cost at iteration 77 :  147402.55706856382
# solving linear deformation equation
# Optimality condition 1.4739936443500688e+16
# cost at iteration 78 :  146341.22070843336
# solving linear deformation equation
# Optimality condition 1.458659010848356e+16
# cost at iteration 79 :  145285.9479077542
# solving linear deformation equation
# Optimality condition 1.4434743139488708e+16
# cost at iteration 80 :  144236.72991484488
# solving linear deformation equation
# Optimality condition 1.4284384562185898e+16
# cost at iteration 81 :  143193.5579483904
# solving linear deformation equation
# Optimality condition 1.4135503459057764e+16
# cost at iteration 82 :  142156.4231974162
# solving linear deformation equation
# Optimality condition 1.3988088969331736e+16
# cost at iteration 83 :  141125.3168212717
# solving linear deformation equation
# Optimality condition 1.3842130288912196e+16
# cost at iteration 84 :  140100.22994963138
# solving linear deformation equation
# Optimality condition 1.3697616670312102e+16
# cost at iteration 85 :  139081.15368250877
# solving linear deformation equation
# Optimality condition 1.3554537422584654e+16
# cost at iteration 86 :  138068.07909027988
# solving linear deformation equation
# Optimality condition 1.3412881911254688e+16
# cost at iteration 87 :  137060.99721373295
# solving linear deformation equation
# Optimality condition 1.327263955824961e+16
# cost at iteration 88 :  136059.89906411563
# solving linear deformation equation
# Optimality condition 1.3133799841830312e+16
# cost at iteration 89 :  135064.77562320663
# solving linear deformation equation
# Optimality condition 1.2996352296521436e+16
# cost at iteration 90 :  134075.6178433979
# solving linear deformation equation
# Optimality condition 1.2860286513041598e+16
# cost at iteration 91 :  133092.41664778968
# solving linear deformation equation
# Optimality condition 1.2725592138232818e+16
# cost at iteration 92 :  132115.16293029636
# solving linear deformation equation
# Optimality condition 1.2592258874989864e+16
# cost at iteration 93 :  131143.84755577068
# solving linear deformation equation
# Optimality condition 1.2460276482188926e+16
# cost at iteration 94 :  130178.46136013561
# solving linear deformation equation
# Optimality condition 1.2329634774615902e+16
# cost at iteration 95 :  129218.9951505317
# solving linear deformation equation
# Optimality condition 1.2200323622893828e+16
# cost at iteration 96 :  128265.43970547205
# solving linear deformation equation
# Optimality condition 1.2072332953410374e+16
# cost at iteration 97 :  127317.78577501835
# solving linear deformation equation
# Optimality condition 1.1945652748244026e+16
# cost at iteration 98 :  126376.02408095846
# solving linear deformation equation
# Optimality condition 1.1820273045090308e+16
# cost at iteration 99 :  125440.14531700476
# solving linear deformation equation
# Optimality condition 1.16961839371868e+16
# cost at iteration 100 :  124510.14014899444
# solving linear deformation equation
# Optimality condition 1.157337557323777e+16
# cost at iteration 101 :  123585.99921511153
# solving linear deformation equation
# Optimality condition 1.1451838157338056e+16
# cost at iteration 102 :  122667.71312610926
# solving linear deformation equation
# Optimality condition 1.1331561948896422e+16
# cost at iteration 103 :  121755.27246555296
# solving linear deformation equation
# Optimality condition 1.121253726255766e+16
# cost at iteration 104 :  120848.66779006452
# solving linear deformation equation
# Optimality condition 1.1094754468124278e+16
# cost at iteration 105 :  119947.88962958299
# solving linear deformation equation
# Optimality condition 1.0978203990477494e+16
# cost at iteration 106 :  119052.92848763116
# solving linear deformation equation
# Optimality condition 1.0862876309497056e+16
# cost at iteration 107 :  118163.77484159512
# solving linear deformation equation
# Optimality condition 1.0748761959980352e+16
# cost at iteration 108 :  117280.41914300871
# solving linear deformation equation
# Optimality condition 1.0635851531560804e+16
# cost at iteration 109 :  116402.85181784992
# solving linear deformation equation
# Optimality condition 1.052413566862504e+16
# cost at iteration 110 :  115531.06326684344
# solving linear deformation equation
# Optimality condition 1.041360507022965e+16
# cost at iteration 111 :  114665.0438657756
# solving linear deformation equation
# Optimality condition 1.0304250490016308e+16
# cost at iteration 112 :  113804.78396580882
# solving linear deformation equation
# Optimality condition 1.0196062736126568e+16
# cost at iteration 113 :  112950.27389381286
# solving linear deformation equation
# Optimality condition 1.0089032671115296e+16
# cost at iteration 114 :  112101.50395269472
# solving linear deformation equation
# Optimality condition 9983151211863290.0
# cost at iteration 115 :  111258.46442174148
# solving linear deformation equation
# Optimality condition 9878409329488754.0
# cost at iteration 116 :  110421.14555696482
# solving linear deformation equation
# Optimality condition 9774798049257764.0
# cost at iteration 117 :  109589.53759145274
# solving linear deformation equation
# Optimality condition 9672308450493648.0
# cost at iteration 118 :  108763.63073572674
# solving linear deformation equation
# Optimality condition 9570931666485376.0
# cost at iteration 119 :  107943.41517810391
# solving linear deformation equation
# Optimality condition 9470658884394754.0
# cost at iteration 120 :  107128.88108506137
# solving linear deformation equation
# Optimality condition 9371481345162418.0
# cost at iteration 121 :  106320.01860160737
# solving linear deformation equation
# Optimality condition 9273390343412824.0
# cost at iteration 122 :  105516.81785165366
# solving linear deformation equation
# Optimality condition 9176377227358004.0
# cost at iteration 123 :  104719.26893838988
# solving linear deformation equation
# Optimality condition 9080433398700168.0
# cost at iteration 124 :  103927.36194466437
# solving linear deformation equation
# Optimality condition 8985550312532937.0
# cost at iteration 125 :  103141.08693336097
# solving linear deformation equation
# Optimality condition 8891719477241588.0
# cost at iteration 126 :  102360.43394778026
# solving linear deformation equation
# Optimality condition 8798932454401854.0
# cost at iteration 127 :  101585.39301202154
# solving linear deformation equation
# Optimality condition 8707180858677500.0
# cost at iteration 128 :  100815.9541313645
# solving linear deformation equation
# Optimality condition 8616456357716708.0
# cost at iteration 129 :  100052.1072926485
# solving linear deformation equation
# Optimality condition 8526750672046827.0
# cost at iteration 130 :  99293.84246465165
# solving linear deformation equation
# Optimality condition 8438055574968309.0
# cost at iteration 131 :  98541.14959847057
# solving linear deformation equation
# Optimality condition 8350362892446618.0
# cost at iteration 132 :  97794.01862789298
# solving linear deformation equation
# Optimality condition 8263664503003297.0
# cost at iteration 133 :  97052.43946976926
# solving linear deformation equation
# Optimality condition 8177952337605168.0
# cost at iteration 134 :  96316.40202437984
# solving linear deformation equation
# Optimality condition 8093218379552600.0
# cost at iteration 135 :  95585.89617580059
# solving linear deformation equation
# Optimality condition 8009454664365663.0
# cost at iteration 136 :  94860.9117922565
# solving linear deformation equation
# Optimality condition 7926653279669372.0
# cost at iteration 137 :  94141.43872647584
# solving linear deformation equation
# Optimality condition 7844806365076784.0
# cost at iteration 138 :  93427.46681603033
# solving linear deformation equation
# Optimality condition 7763906112071076.0
# cost at iteration 139 :  92718.98588367424
# solving linear deformation equation
# Optimality condition 7683944763885788.0
# cost at iteration 140 :  92015.98573767174
# solving linear deformation equation
# Optimality condition 7604914615383187.0
# cost at iteration 141 :  91318.45617211192
# solving linear deformation equation
# Optimality condition 7526808012931242.0
# cost at iteration 142 :  90626.38696721729
# solving linear deformation equation
# Optimality condition 7449617354278842.0
# cost at iteration 143 :  89939.7678896385
# solving linear deformation equation
# Optimality condition 7373335088429062.0
# cost at iteration 144 :  89258.58869273824
# solving linear deformation equation
# Optimality condition 7297953715510766.0
# cost at iteration 145 :  88582.83911685897
# solving linear deformation equation
# Optimality condition 7223465786648233.0
# cost at iteration 146 :  87912.50888957757
# solving linear deformation equation
# Optimality condition 7149863903828996.0
# cost at iteration 147 :  87247.5877259437
# solving linear deformation equation
# Optimality condition 7077140719769556.0
# cost at iteration 148 :  86588.06532870255
# solving linear deformation equation
# Optimality condition 7005288937779184.0
# cost at iteration 149 :  85933.93138849737
# solving linear deformation equation
# Optimality condition 6934301311621604.0
# cost at iteration 150 :  85285.17558405314
# solving linear deformation equation
# Optimality condition 6864170645374476.0
# cost at iteration 151 :  84641.7875823405
# solving linear deformation equation
# Optimality condition 6794889793286767.0
# cost at iteration 152 :  84003.75703871725
# solving linear deformation equation
# Optimality condition 6726451659633672.0
# cost at iteration 153 :  83371.07359704486
# solving linear deformation equation
# Optimality condition 6658849198569436.0
# cost at iteration 154 :  82743.72688978279
# solving linear deformation equation
# Optimality condition 6592075413977452.0
# cost at iteration 155 :  82121.70653805415
# solving linear deformation equation
# Optimality condition 6526123359318062.0
# cost at iteration 156 :  81505.00215168382
# solving linear deformation equation
# Optimality condition 6460986137473623.0
# cost at iteration 157 :  80893.60332920795
# solving linear deformation equation
# Optimality condition 6396656900590952.0
# cost at iteration 158 :  80287.49965784936
# solving linear deformation equation
# Optimality condition 6333128849921070.0
# cost at iteration 159 :  79686.6807134664
# solving linear deformation equation
# Optimality condition 6270395235655729.0
# cost at iteration 160 :  79091.13606045401
# solving linear deformation equation
# Optimality condition 6208449356761476.0
# cost at iteration 161 :  78500.85525162495
# solving linear deformation equation
# Optimality condition 6147284560810066.0
# cost at iteration 162 :  77915.82782803565
# solving linear deformation equation
# Optimality condition 6086894243806088.0
# cost at iteration 163 :  77336.0433187821
# solving linear deformation equation
# Optimality condition 6027271850011068.0
# cost at iteration 164 :  76761.4912407486
# solving linear deformation equation
# Optimality condition 5968410871764108.0
# cost at iteration 165 :  76192.16109830969
# solving linear deformation equation
# Optimality condition 5910304849298926.0
# cost at iteration 166 :  75628.0423829846
# solving linear deformation equation
# Optimality condition 5852947370557305.0
# cost at iteration 167 :  75069.1245730457
# solving linear deformation equation
# Optimality condition 5796332070998506.0
# cost at iteration 168 :  74515.39713306728
# solving linear deformation equation
# Optimality condition 5740452633404700.0
# cost at iteration 169 :  73966.84951342316
# solving linear deformation equation
# Optimality condition 5685302787682219.0
# cost at iteration 170 :  73423.47114972425
# solving linear deformation equation
# Optimality condition 5630876310658512.0
# cost at iteration 171 :  72885.25146219514
# solving linear deformation equation
# Optimality condition 5577167025874470.0
# cost at iteration 172 :  72352.17985498659
# solving linear deformation equation
# Optimality condition 5524168803372120.0
# cost at iteration 173 :  71824.24571542062
# solving linear deformation equation
# Optimality condition 5471875559477318.0
# cost at iteration 174 :  71301.43841316222
# solving linear deformation equation
# Optimality condition 5420281256577600.0
# cost at iteration 175 :  70783.7472993227
# solving linear deformation equation
# Optimality condition 5369379902894380.0
# cost at iteration 176 :  70271.1617054782
# solving linear deformation equation
# Optimality condition 5319165552249932.0
# cost at iteration 177 :  69763.67094261198
# solving linear deformation equation
# Optimality condition 5269632303828562.0
# cost at iteration 178 :  69261.26429997226
# solving linear deformation equation
# Optimality condition 5220774301931666.0
# cost at iteration 179 :  68763.93104383336
# solving linear deformation equation
# Optimality condition 5172585735726880.0
# cost at iteration 180 :  68271.66041617405
# solving linear deformation equation
# Optimality condition 5125060838990555.0
# cost at iteration 181 :  67784.44163325135
# solving linear deformation equation
# Optimality condition 5078193889843615.0
# cost at iteration 182 :  67302.263884075
# solving linear deformation equation
# Optimality condition 5031979210480463.0
# cost at iteration 183 :  66825.11632877475
# solving linear deformation equation
# Optimality condition 4986411166890696.0
# cost at iteration 184 :  66352.98809685801
# solving linear deformation equation
# Optimality condition 4941484168573205.0
# cost at iteration 185 :  65885.86828535135
# solving linear deformation equation
# Optimality condition 4897192668242558.0
# cost at iteration 186 :  65423.74595681918
# solving linear deformation equation
# Optimality condition 4853531161527251.0
# cost at iteration 187 :  64966.61013725951
# solving linear deformation equation
# Optimality condition 4810494186659578.0
# cost at iteration 188 :  64514.449813867206
# solving linear deformation equation
# Optimality condition 4768076324156764.0
# cost at iteration 189 :  64067.25393266011
# solving linear deformation equation
# Optimality condition 4726272196493070.0
# cost at iteration 190 :  63625.01139596341
# solving linear deformation equation
# Optimality condition 4685076467762454.0
# cost at iteration 191 :  63187.71105974588
# solving linear deformation equation
# Optimality condition 4644483843331739.0
# cost at iteration 192 :  62755.34173080514
# solving linear deformation equation
# Optimality condition 4604489069483402.0
# cost at iteration 193 :  62327.892163787365
# solving linear deformation equation
# Optimality condition 4565086933048251.0
# cost at iteration 194 :  61905.351058046566
# solving linear deformation equation
# Optimality condition 4526272261027218.0
# cost at iteration 195 :  61487.707054330494
# solving linear deformation equation
# Optimality condition 4488039920202036.0
# cost at iteration 196 :  61074.94873128635
# solving linear deformation equation
# Optimality condition 4450384816734423.5
# cost at iteration 197 :  60667.0646017847
# solving linear deformation equation
# Optimality condition 4413301895753554.5
# cost at iteration 198 :  60264.04310905086
# solving linear deformation equation
# Optimality condition 4376786140931032.0
# cost at iteration 199 :  59865.87262259787
# solving linear deformation equation
# Optimality condition 4340832574043585.0
# cost at iteration 200 :  59472.54143395809
# solving linear deformation equation
# Optimality condition 4305436254522489.0
# cost at iteration 201 :  59084.03775219904
# solving linear deformation equation
# Optimality condition 4270592278990012.0
# cost at iteration 202 :  58700.34969923085
# solving linear deformation equation
# Optimality condition 4236295780781800.0
# cost at iteration 203 :  58321.4653048801
# solving linear deformation equation
# Optimality condition 4202541929455396.0
# cost at iteration 204 :  57947.37250174023
# solving linear deformation equation
# Optimality condition 4169325930284308.5
# cost at iteration 205 :  57578.0591197827
# solving linear deformation equation
# Optimality condition 4136643023737261.0
# cost at iteration 206 :  57213.51288072604
# solving linear deformation equation
# Optimality condition 4104488484942465.0
# cost at iteration 207 :  56853.721392159256
# solving linear deformation equation
# Optimality condition 4072857623136202.5
# cost at iteration 208 :  56498.672141403746
# solving linear deformation equation
# Optimality condition 4041745781095968.0
# cost at iteration 209 :  56148.3524891234
# solving linear deformation equation
# Optimality condition 4011148334557398.0
# cost at iteration 210 :  55802.74966266501
# solving linear deformation equation
# Optimality condition 3981060691614905.5
# cost at iteration 211 :  55461.85074912828
# solving linear deformation equation
# Optimality condition 3951478292105774.0
# cost at iteration 212 :  55125.64268816281
# solving linear deformation equation
# Optimality condition 3922396606977667.0
# cost at iteration 213 :  54794.11226449043
# solving linear deformation equation
# Optimality condition 3893811137638790.0
# cost at iteration 214 :  54467.24610013523
# solving linear deformation equation
# Optimality condition 3865717415291437.5
# cost at iteration 215 :  54145.030646383275
# solving linear deformation equation
# Optimality condition 3838111000247850.0
# cost at iteration 216 :  53827.45217544239
# solving linear deformation equation
# Optimality condition 3810987481229188.0
# cost at iteration 217 :  53514.496771824306
# solving linear deformation equation
# Optimality condition 3784342474646920.0
# cost at iteration 218 :  53206.150323432514
# solving linear deformation equation
# Optimality condition 3758171623867043.0
# cost at iteration 219 :  52902.398512364
# solving linear deformation equation
# Optimality condition 3732470598457203.0
# cost at iteration 220 :  52603.22680542731
# solving linear deformation equation
# Optimality condition 3707235093416596.5
# cost at iteration 221 :  52308.620444372915
# solving linear deformation equation
# Optimality condition 3682460828389181.0
# cost at iteration 222 :  52018.564435846565
# solving linear deformation equation
# Optimality condition 3658143546860311.0
# cost at iteration 223 :  51733.04354106713
# solving linear deformation equation
# Optimality condition 3634279015337346.0
# cost at iteration 224 :  51452.0422652404
# solving linear deformation equation
# Optimality condition 3610863022514288.5
# cost at iteration 225 :  51175.54484670544
# solving linear deformation equation
# Optimality condition 3587891378421579.5
# cost at iteration 226 :  50903.535245840416
# solving linear deformation equation
# Optimality condition 3565359913561074.0
# cost at iteration 227 :  50635.99713372103
# solving linear deformation equation
# Optimality condition 3543264478027543.0
# cost at iteration 228 :  50372.91388056297
# solving linear deformation equation
# Optimality condition 3521600940616954.0
# cost at iteration 229 :  50114.26854394645
# solving linear deformation equation
# Optimality condition 3500365187922991.0
# cost at iteration 230 :  49860.043856854376
# solving linear deformation equation
# Optimality condition 3479553123422487.0
# cost at iteration 231 :  49610.2222155323
# solving linear deformation equation
# Optimality condition 3459160666551373.0
# cost at iteration 232 :  49364.78566720214
# solving linear deformation equation
# Optimality condition 3439183751771967.5
# cost at iteration 233 :  49123.71589764254
# solving linear deformation equation
# Optimality condition 3419618327633570.5
# cost at iteration 234 :  48886.99421867149
# solving linear deformation equation
# Optimality condition 3400460355827627.5
# cost at iteration 235 :  48654.60155555629
# solving linear deformation equation
# Optimality condition 3381705810239151.5
# cost at iteration 236 :  48426.518434376354
# solving linear deformation equation
# Optimality condition 3363350675996616.0
# cost at iteration 237 :  48202.7249693847
# solving linear deformation equation
# Optimality condition 3345390948521916.0
# cost at iteration 238 :  47983.200850391375
# solving linear deformation equation
# Optimality condition 3327822632582831.0
# cost at iteration 239 :  47767.925330216516
# solving linear deformation equation
# Optimality condition 3310641741350063.0
# cost at iteration 240 :  47556.877212246676
# solving linear deformation equation
# Optimality condition 3293844295461530.5
# cost at iteration 241 :  47350.03483814562
# solving linear deformation equation
# Optimality condition 3277426322096351.5
# cost at iteration 242 :  47147.376075761065
# solving linear deformation equation
# Optimality condition 3261383854061050.5
# cost at iteration 243 :  46948.87830727181
# solving linear deformation equation
# Optimality condition 3245712928891208.0
# cost at iteration 244 :  46754.51841763443
# solving linear deformation equation
# Optimality condition 3230409587971249.5
# cost at iteration 245 :  46564.27278337646
# solving linear deformation equation
# Optimality condition 3215469875675449.5
# cost at iteration 246 :  46378.11726178817
# solving linear deformation equation
# Optimality condition 3200889838533512.0
# cost at iteration 247 :  46196.02718057707
# solving linear deformation equation
# Optimality condition 3186665524423765.0
# cost at iteration 248 :  46017.97732803165
# solving linear deformation equation
# Optimality condition 3172792981797612.0
# cost at iteration 249 :  45843.9419437655
# solving linear deformation equation
# Optimality condition 3159268258938389.5
# cost at iteration 250 :  45673.894710089226
# solving linear deformation equation
# Optimality condition 3146087403258314.5
# cost at iteration 251 :  45507.80874407898
# solving linear deformation equation
# Optimality condition 3133246460636989.0
# cost at iteration 252 :  45345.65659040023
# solving linear deformation equation
# Optimality condition 3120741474804928.0
# cost at iteration 253 :  45187.410214943855
# solving linear deformation equation
# Optimality condition 3108568486775724.0
# cost at iteration 254 :  45033.04099933909
# solving linear deformation equation
# Optimality condition 3096723534330225.0
# cost at iteration 255 :  44882.519736397255
# solving linear deformation equation
# Optimality condition 3085202651556371.5
# cost at iteration 256 :  44735.816626551554
# solving linear deformation equation
# Optimality condition 3074001868447851.5
# cost at iteration 257 :  44592.90127534047
# solving linear deformation equation
# Optimality condition 3063117210564872.5
# cost at iteration 258 :  44453.7426919925
# solving linear deformation equation
# Optimality condition 3052544698760303.0
# cost at iteration 259 :  44318.309289164084
# solving linear deformation equation
# Optimality condition 3042280348973948.0
# cost at iteration 260 :  44186.56888387411
# solving linear deformation equation
# Optimality condition 3032320172097941.0
# cost at iteration 261 :  44058.48869968463
# solving linear deformation equation
# Optimality condition 3022660173915649.0
# cost at iteration 262 :  43934.035370161124
# solving linear deformation equation
# Optimality condition 3013296355116430.5
# cost at iteration 263 :  43813.17494365042
# solving linear deformation equation
# Optimality condition 3004224711388395.0
# cost at iteration 264 :  43695.8728894077
# solving linear deformation equation
# Optimality condition 2995441233590765.0
# cost at iteration 265 :  43582.094105091135
# solving linear deformation equation
# Optimality condition 2986941908007339.0
# cost at iteration 266 :  43471.802925649536
# solving linear deformation equation
# Optimality condition 2978722716682070.0
# cost at iteration 267 :  43364.96313360669
# solving linear deformation equation
# Optimality condition 2970779637837569.0
# cost at iteration 268 :  43261.53797075723
# solving linear deformation equation
# Optimality condition 2963108646376627.0
# cost at iteration 269 :  43161.49015126106
# solving linear deformation equation
# Optimality condition 2955705714466951.5
# cost at iteration 270 :  43064.78187613995
# solving linear deformation equation
# Optimality condition 2948566812208280.0
# cost at iteration 271 :  42971.374849147374
# solving linear deformation equation
# Optimality condition 2941687908381281.0
# cost at iteration 272 :  42881.23029400192
# solving linear deformation equation
# Optimality condition 2935064971276506.0
# cost at iteration 273 :  42794.30897294067
# solving linear deformation equation
# Optimality condition 2928693969601770.5
# cost at iteration 274 :  42710.571206560926
# solving linear deformation equation
# Optimality condition 2922570873465798.0
# cost at iteration 275 :  42629.97689490896
# solving linear deformation equation
# Optimality condition 2916691655435139.5
# cost at iteration 276 :  42552.48553975291
# solving linear deformation equation
# Optimality condition 2911052291661579.0
# cost at iteration 277 :  42478.05626799142
# solving linear deformation equation
# Optimality condition 2905648763076293.5
# cost at iteration 278 :  42406.64785612614
# solving linear deformation equation
# Optimality condition 2900477056646835.0
# cost at iteration 279 :  42338.21875572668
# solving linear deformation equation
# Optimality condition 2895533166692879.0
# cost at iteration 280 :  42272.727119816496
# solving linear deformation equation
# Optimality condition 2890813096255771.5
# cost at iteration 281 :  42210.13083008934
# solving linear deformation equation
# Optimality condition 2886312858517233.0
# cost at iteration 282 :  42150.387524877195
# solving linear deformation equation
# Optimality condition 2882028478261699.0
# cost at iteration 283 :  42093.45462777086
# solving linear deformation equation
# Optimality condition 2877955993377064.0
# cost at iteration 284 :  42039.28937680903
# solving linear deformation equation
# Optimality condition 2874091456387874.0
# cost at iteration 285 :  41987.84885412826
# solving linear deformation equation
# Optimality condition 2870430936015247.0
# cost at iteration 286 :  41939.090015981645
# solving linear deformation equation
# Optimality condition 2866970518757544.0
# cost at iteration 287 :  41892.96972302902
# solving linear deformation equation
# Optimality condition 2863706310485269.5
# cost at iteration 288 :  41849.444770781905
# solving linear deformation equation
# Optimality condition 2860634438044856.0
# cost at iteration 289 :  41808.47192013124
# solving linear deformation equation
# Optimality condition 2857751050864121.5
# cost at iteration 290 :  41770.00792782333
# solving linear deformation equation
# Optimality condition 2855052322554222.0
# cost at iteration 291 :  41734.009576818076
# solving linear deformation equation
# Optimality condition 2852534452501284.0
# cost at iteration 292 :  41700.43370640566
# solving linear deformation equation
# Optimality condition 2850193667442401.5
# cost at iteration 293 :  41669.23724201327
# solving linear deformation equation
# Optimality condition 2848026223019765.0
# cost at iteration 294 :  41640.37722459079
# solving linear deformation equation
# Optimality condition 2846028405307429.0
# cost at iteration 295 :  41613.81083949923
# solving linear deformation equation
# Optimality condition 2844196532305627.5
# cost at iteration 296 :  41589.49544482193
# solving linear deformation equation
# Optimality condition 2842526955397089.0
# cost at iteration 297 :  41567.38859901152
# solving linear deformation equation
# Optimality condition 2841016060760970.0
# cost at iteration 298 :  41547.44808781308
# solving linear deformation equation
# Optimality condition 2839660270739560.0
# cost at iteration 299 :  41529.63195038255
# solving linear deformation equation
# Optimality condition 2838456045153766.0
# cost at iteration 300 :  41513.89850455019
# solving linear deformation equation
# Optimality condition 2837399882563574.5
# cost at iteration 301 :  41500.20637117008
# solving linear deformation equation
# Optimality condition 2836488321469876.0
# cost at iteration 302 :  41488.51449750199
# solving linear deformation equation
# Optimality condition 2835717941454765.0
# cost at iteration 303 :  41478.78217958983
# solving linear deformation equation
# Optimality condition 2835085364257567.0
# cost at iteration 304 :  41470.96908359514
# solving linear deformation equation
# Optimality condition 2834587254784059.0
# cost at iteration 305 :  41465.03526604896
# solving linear deformation equation
# Optimality condition 2834220322047428.0
# cost at iteration 306 :  41460.9411930113
# solving linear deformation equation
# Optimality condition 2833981320038915.0
# cost at iteration 307 :  41458.647758100386
# solving linear deformation equation
# Optimality condition 2833867048527411.0
# cost at iteration 308 :  41458.116299395486
# solving linear deformation equation
# Optimality condition 2833874353786922.0
# cost at iteration 309 :  41459.30861519144
# solving linear deformation equation
# Optimality condition 2834000129251577.0
# cost at iteration 310 :  41462.18697860726
# solving linear deformation equation
# Optimality condition 2834241316098203.0
# cost at iteration 311 :  41466.7141510553
# solving linear deformation equation
# Optimality condition 2834594903756418.0
# cost at iteration 312 :  41472.853394566395
# solving linear deformation equation
# Optimality condition 2835057930347076.5
# cost at iteration 313 :  41480.5684829934
# solving linear deformation equation
# Optimality condition 2835627483049755.0
# cost at iteration 314 :  41489.823712102676
# solving linear deformation equation
# Optimality condition 2836300698400320.0
# cost at iteration 315 :  41500.583908569235
# solving linear deformation equation
# Optimality condition 2837074762520185.0
# cost at iteration 316 :  41512.81443790787
# solving linear deformation equation
# Optimality condition 2837946911278499.0
# cost at iteration 317 :  41526.48121135468
# solving linear deformation equation
# Optimality condition 2838914430389390.0
# cost at iteration 318 :  41541.550691736134
# solving linear deformation equation
# Optimality condition 2839974655445945.0
# cost at iteration 319 :  41557.98989834892
# solving linear deformation equation
# Optimality condition 2841124971893284.0
# cost at iteration 320 :  41575.766410889686
# solving linear deformation equation
# Optimality condition 2842362814942818.0
# cost at iteration 321 :  41594.848372462795
# solving linear deformation equation
# Optimality condition 2843685669430293.5
# cost at iteration 322 :  41615.20449171019
# solving linear deformation equation
# Optimality condition 2845091069619896.0
# cost at iteration 323 :  41636.804044092445
# solving linear deformation equation
# Optimality condition 2846576598957165.0
# cost at iteration 324 :  41659.61687236592
# solving linear deformation equation
# Optimality condition 2848139889773146.5
# cost at iteration 325 :  41683.613386286124
# solving linear deformation equation
# Optimality condition 2849778622942760.0
# cost at iteration 326 :  41708.76456159012
# solving linear deformation equation
# Optimality condition 2851490527499726.0
# cost at iteration 327 :  41735.04193828209
# solving linear deformation equation
# Optimality condition 2853273380211074.0
# cost at iteration 328 :  41762.417618274594
# solving linear deformation equation
# Optimality condition 2855125005113631.0
# cost at iteration 329 :  41790.86426241257
# solving linear deformation equation
# Optimality condition 2857043273015476.0
# cost at iteration 330 :  41820.35508693032
# solving linear deformation equation
# Optimality condition 2859026100964873.0
# cost at iteration 331 :  41850.86385937539
# solving linear deformation equation
# Optimality condition 2861071451689163.0
# cost at iteration 332 :  41882.3648940299
# solving linear deformation equation
# Optimality condition 2863177333006400.0
# cost at iteration 333 :  41914.83304687784
# solving linear deformation equation
# Optimality condition 2865341797212191.0
# cost at iteration 334 :  41948.24371014762
# solving linear deformation equation
# Optimality condition 2867562940443950.0
# cost at iteration 335 :  41982.57280646309
# solving linear deformation equation
# Optimality condition 2869838902025292.5
# cost at iteration 336 :  42017.79678264345
# solving linear deformation equation
# Optimality condition 2872167863792478.0
# cost at iteration 337 :  42053.892603176224
# solving linear deformation equation
# Optimality condition 2874548049405436.5
# cost at iteration 338 :  42090.83774340455
# solving linear deformation equation
# Optimality condition 2876977723645163.0
# cost at iteration 339 :  42128.61018244718
# solving linear deformation equation
# Optimality condition 2879455191699746.0
# cost at iteration 340 :  42167.18839589078
# solving linear deformation equation
# Optimality condition 2881978798440810.0
# cost at iteration 341 :  42206.55134827527
# solving linear deformation equation
# Optimality condition 2884546927692381.0
# cost at iteration 342 :  42246.67848540465
# solving linear deformation equation
# Optimality condition 2887158001493539.0
# cost at iteration 343 :  42287.549726496356
# solving linear deformation equation
# Optimality condition 2889810479357023.0
# cost at iteration 344 :  42329.14545621165
# solving linear deformation equation
# Optimality condition 2892502857524825.0
# cost at iteration 345 :  42371.446516568074
# solving linear deformation equation
# Optimality condition 2895233668222607.5
# cost at iteration 346 :  42414.43419877304
# solving linear deformation equation
# Optimality condition 2898001478914115.0
# cost at iteration 347 :  42458.09023498871
# solving linear deformation equation
# Optimality condition 2900804891556779.0
# cost at iteration 348 :  42502.396790044215
# solving linear deformation equation
# Optimality condition 2903642541860129.5
# cost at iteration 349 :  42547.336453129385
# solving linear deformation equation
# Optimality condition 2906513098547240.0
# cost at iteration 350 :  42592.89222945332
# solving linear deformation equation
# Optimality condition 2909415262621503.5
# cost at iteration 351 :  42639.04753193162
# solving linear deformation equation
# Optimality condition 2912347766638228.0
# cost at iteration 352 :  42685.786172859785
# solving linear deformation equation
# Optimality condition 2915309373983206.0
# cost at iteration 353 :  42733.09235563775
# solving linear deformation equation
# Optimality condition 2918298878158014.0
# cost at iteration 354 :  42780.9506665153
# solving linear deformation equation
# Optimality condition 2921315102073596.0
# cost at iteration 355 :  42829.3460664056
# solving linear deformation equation
# Optimality condition 2924356897352040.0
# cost at iteration 356 :  42878.26388274314
# solving linear deformation equation
# Optimality condition 2927423143637660.0
# cost at iteration 357 :  42927.68980142178
# solving linear deformation equation
# Optimality condition 2930512747917697.5
# cost at iteration 358 :  42977.60985880937
# solving linear deformation equation
# Optimality condition 2933624643853055.0
# cost at iteration 359 :  43028.01043384518
# solving linear deformation equation
# Optimality condition 2936757791119535.0
# cost at iteration 360 :  43078.87824023312
# solving linear deformation equation
# Optimality condition 2939911174759916.0
# cost at iteration 361 :  43130.20031872908
# solving linear deformation equation
# Optimality condition 2943083804547329.0
# cost at iteration 362 :  43181.964029542825
# solving linear deformation equation
# Optimality condition 2946274714359639.0
# cost at iteration 363 :  43234.157044830295
# solving linear deformation equation
# Optimality condition 2949482961565953.5
# cost at iteration 364 :  43286.767341320156
# solving linear deformation equation
# Optimality condition 2952707626424572.0
# cost at iteration 365 :  43339.78319304318
# solving linear deformation equation
# Optimality condition 2955947811492908.5
# cost at iteration 366 :  43393.193164183795
# solving linear deformation equation
# Optimality condition 2959202641049579.0
# cost at iteration 367 :  43446.98610205839
# solving linear deformation equation
# Optimality condition 2962471260528437.5
# cost at iteration 368 :  43501.151130214224
# solving linear deformation equation
# Optimality condition 2965752835964806.0
# cost at iteration 369 :  43555.67764165625
# solving linear deformation equation
# Optimality condition 2969046553453832.0
# cost at iteration 370 :  43610.555292201745
# solving linear deformation equation
# Optimality condition 2972351618621045.5
# cost at iteration 371 :  43665.7739939651
# solving linear deformation equation
# Optimality condition 2975667256104855.0
# cost at iteration 372 :  43721.323908968305
# solving linear deformation equation
# Optimality condition 2978992709051183.0
# cost at iteration 373 :  43777.19544288476
# solving linear deformation equation
# Optimality condition 2982327238620076.0
# cost at iteration 374 :  43833.37923891266
# solving linear deformation equation
# Optimality condition 2985670123504112.5
# cost at iteration 375 :  43889.86617177744
# solving linear deformation equation
# Optimality condition 2989020659458536.0
# cost at iteration 376 :  43946.64734186259
# solving linear deformation equation
# Optimality condition 2992378158843052.0
# cost at iteration 377 :  44003.71406947034
# solving linear deformation equation
# Optimality condition 2995741950175214.0
# cost at iteration 378 :  44061.057889214884
# solving linear deformation equation
# Optimality condition 2999111377694780.0
# cost at iteration 379 :  44118.67054452908
# solving linear deformation equation
# Optimality condition 3002485800939802.5
# cost at iteration 380 :  44176.54398231674
# solving linear deformation equation
# Optimality condition 3005864594333141.0
# cost at iteration 381 :  44234.67034771051
# solving linear deformation equation
# Optimality condition 3009247146780097.0
# cost at iteration 382 :  44293.04197896101
# solving linear deformation equation
# Optimality condition 3012632861276867.0
# cost at iteration 383 :  44351.651402456075
# solving linear deformation equation
# Optimality condition 3016021154528931.0
# cost at iteration 384 :  44410.49132783957
# solving linear deformation equation
# Optimality condition 3019411456580252.0
# cost at iteration 385 :  44469.554643269315
# solving linear deformation equation
# Optimality condition 3022803210452142.0
# cost at iteration 386 :  44528.834410776224
# solving linear deformation equation
# Optimality condition 3026195871792219.0
# cost at iteration 387 :  44588.32386174707
# solving linear deformation equation
# Optimality condition 3029588908532929.0
# cost at iteration 388 :  44648.01639251585
# solving linear deformation equation
# Optimality condition 3032981800559499.5
# cost at iteration 389 :  44707.90556006436
# solving linear deformation equation
# Optimality condition 3036374039387247.0
# cost at iteration 390 :  44767.98507783682
# solving linear deformation equation
# Optimality condition 3039765127847792.0
# cost at iteration 391 :  44828.24881165372
# solving linear deformation equation
# Optimality condition 3043154579784258.0
# cost at iteration 392 :  44888.69077573708
# solving linear deformation equation
# Optimality condition 3046541919754917.0
# cost at iteration 393 :  44949.30512883112
# solving linear deformation equation
# Optimality condition 3049926682745522.0
# cost at iteration 394 :  45010.086170431015
# solving linear deformation equation
# Optimality condition 3053308413889543.0
# cost at iteration 395 :  45071.02833710092
# ...
# solving linear deformation equation
# Optimality condition 2422424388574995.0
# cost at iteration 870 :  68445.32155515639
# solving linear deformation equation
# Optimality condition 2416993757105187.0
# cost at iteration 871 :  68471.66140803507
# solving linear deformation equation
# Optimality condition 2411555540503138.5
# cost at iteration 872 :  68497.89895546623
# solving linear deformation equation
# Optimality condition 2406109802219512.5
# cost at iteration 873 :  68524.03423957841
# solving linear deformation equation
# Optimality condition 2400656605502040.0
# cost at iteration 874 :  68550.06730269376
# solving linear deformation equation
# Optimality condition 2395196013394185.0
# cost at iteration 875 :  68575.99818731144
# solving linear deformation equation
# Optimality condition 2389728088733933.5
# cost at iteration 876 :  68601.8269361025
# solving linear deformation equation
# Optimality condition 2384252894152685.5
# cost at iteration 877 :  68627.55359190503
# solving linear deformation equation
# Optimality condition 2378770492073991.0
# cost at iteration 878 :  68653.17819771197
# solving linear deformation equation
# Optimality condition 2373280944712713.0
# cost at iteration 879 :  68678.70079668413
# solving linear deformation equation
# Optimality condition 2367784314073571.0
# cost at iteration 880 :  68704.12143212414
# solving linear deformation equation
# Optimality condition 2362280661949955.0
# cost at iteration 881 :  68729.44014746588
# solving linear deformation equation
# Optimality condition 2356770049923162.0
# cost at iteration 882 :  68754.65698628705
# solving linear deformation equation
# Optimality condition 2351252539361235.0
# cost at iteration 883 :  68779.77199230243
# solving linear deformation equation
# Optimality condition 2345728191417457.5
# cost at iteration 884 :  68804.78520932911
# solving linear deformation equation
# Optimality condition 2340197067029939.0
# cost at iteration 885 :  68829.69668131921
# solving linear deformation equation
# Optimality condition 2334659226919849.0
# cost at iteration 886 :  68854.50645231207
# solving linear deformation equation
# Optimality condition 2329114731591047.0
# cost at iteration 887 :  68879.21456646804
# solving linear deformation equation
# Optimality condition 2323563641328481.0
# cost at iteration 888 :  68903.82106802688
# solving linear deformation equation
# Optimality condition 2318006016197461.5
# cost at iteration 889 :  68928.32600132049
# solving linear deformation equation
# Optimality condition 2312441916042667.0
# cost at iteration 890 :  68952.72941076363
# solving linear deformation equation
# Optimality condition 2306871400487051.0
# cost at iteration 891 :  68977.03134084589
# solving linear deformation equation
# Optimality condition 2301294528930752.5
# cost at iteration 892 :  69001.23183611514
# solving linear deformation equation
# Optimality condition 2295711360550184.0
# cost at iteration 893 :  69025.33094117513
# solving linear deformation equation
# Optimality condition 2290121954297381.0
# cost at iteration 894 :  69049.32870069885
# solving linear deformation equation
# Optimality condition 2284526368898363.0
# cost at iteration 895 :  69073.22515937728
# solving linear deformation equation
# Optimality condition 2278924662852962.0
# cost at iteration 896 :  69097.02036196139
# solving linear deformation equation
# Optimality condition 2273316894433220.0
# cost at iteration 897 :  69120.7143532118
# solving linear deformation equation
# Optimality condition 2267703121682910.0
# cost at iteration 898 :  69144.30717792055
# solving linear deformation equation
# Optimality condition 2262083402416496.5
# cost at iteration 899 :  69167.7988808928
# solving linear deformation equation
# Optimality condition 2256457794218043.0
# cost at iteration 900 :  69191.18950692809
# solving linear deformation equation
# Optimality condition 2250826354440664.8
# cost at iteration 901 :  69214.47910083618
# solving linear deformation equation
# Optimality condition 2245189140205360.8
# cost at iteration 902 :  69237.66770740757
# solving linear deformation equation
# Optimality condition 2239546208400282.0
# cost at iteration 903 :  69260.75537141594
# solving linear deformation equation
# Optimality condition 2233897615679742.0
# cost at iteration 904 :  69283.74213759936
# solving linear deformation equation
# Optimality condition 2228243418463754.0
# cost at iteration 905 :  69306.62805067953
# solving linear deformation equation
# Optimality condition 2222583672936662.0
# cost at iteration 906 :  69329.41315531667
# solving linear deformation equation
# Optimality condition 2216918435046586.0
# cost at iteration 907 :  69352.09749611965
# solving linear deformation equation
# Optimality condition 2211247760504743.5
# cost at iteration 908 :  69374.68111764477
# solving linear deformation equation
# Optimality condition 2205571704784390.0
# cost at iteration 909 :  69397.16406437443
# solving linear deformation equation
# Optimality condition 2199890323120173.0
# cost at iteration 910 :  69419.54638070895
# solving linear deformation equation
# Optimality condition 2194203670507210.5
# cost at iteration 911 :  69441.82811095919
# solving linear deformation equation
# Optimality condition 2188511801700658.0
# cost at iteration 912 :  69464.00929935362
# solving linear deformation equation
# Optimality condition 2182814771214432.8
# cost at iteration 913 :  69486.0899899928
# solving linear deformation equation
# Optimality condition 2177112633321020.2
# cost at iteration 914 :  69508.07022688519
# solving linear deformation equation
# Optimality condition 2171405442050281.8
# cost at iteration 915 :  69529.9500538971
# solving linear deformation equation
# Optimality condition 2165693251188992.5
# cost at iteration 916 :  69551.7295147702
# solving linear deformation equation
# Optimality condition 2159976114280042.0
# cost at iteration 917 :  69573.40865310135
# solving linear deformation equation
# Optimality condition 2154254084621803.0
# cost at iteration 918 :  69594.98751233632
# solving linear deformation equation
# Optimality condition 2148527215267230.0
# cost at iteration 919 :  69616.46613575316
# solving linear deformation equation
# Optimality condition 2142795559023512.2
# cost at iteration 920 :  69637.84456646435
# solving linear deformation equation
# Optimality condition 2137059168451075.8
# cost at iteration 921 :  69659.12284739572
# solving linear deformation equation
# Optimality condition 2131318095863124.5
# cost at iteration 922 :  69680.30102128185
# solving linear deformation equation
# Optimality condition 2125572393324972.8
# cost at iteration 923 :  69701.3791306566
# solving linear deformation equation
# Optimality condition 2119822112653287.5
# cost at iteration 924 :  69722.35721783778
# solving linear deformation equation
# Optimality condition 2114067305415672.8
# cost at iteration 925 :  69743.23532492721
# solving linear deformation equation
# Optimality condition 2108308022929814.5
# cost at iteration 926 :  69764.01349378399
# solving linear deformation equation
# Optimality condition 2102544316263023.0
# cost at iteration 927 :  69784.69176602623
# solving linear deformation equation
# Optimality condition 2096776236231739.0
# cost at iteration 928 :  69805.27018302468
# solving linear deformation equation
# Optimality condition 2091003833400669.0
# cost at iteration 929 :  69825.74878587233
# solving linear deformation equation
# Optimality condition 2085227158082506.8
# cost at iteration 930 :  69846.12761539446
# solving linear deformation equation
# Optimality condition 2079446260337190.2
# cost at iteration 931 :  69866.40671212357
# solving linear deformation equation
# Optimality condition 2073661189971493.5
# cost at iteration 932 :  69886.58611629771
# solving linear deformation equation
# Optimality condition 2067871996538288.2
# cost at iteration 933 :  69906.66586783534
# solving linear deformation equation
# Optimality condition 2062078729336328.0
# cost at iteration 934 :  69926.64600634224
# solving linear deformation equation
# Optimality condition 2056281437409530.5
# cost at iteration 935 :  69946.5265710897
# solving linear deformation equation
# Optimality condition 2050480169546421.8
# cost at iteration 936 :  69966.3076009934
# solving linear deformation equation
# Optimality condition 2044674974279920.5
# cost at iteration 937 :  69985.989134626
# solving linear deformation equation
# Optimality condition 2038865899886528.0
# cost at iteration 938 :  70005.57121017366
# solving linear deformation equation
# Optimality condition 2033052994386288.0
# cost at iteration 939 :  70025.05386546043
# solving linear deformation equation
# Optimality condition 2027236305541938.2
# cost at iteration 940 :  70044.43713790269
# solving linear deformation equation
# Optimality condition 2021415880858671.8
# cost at iteration 941 :  70063.72106451276
# solving linear deformation equation
# Optimality condition 2015591767583677.0
# cost at iteration 942 :  70082.90568188125
# solving linear deformation equation
# Optimality condition 2009764012705871.5
# cost at iteration 943 :  70101.99102617527
# solving linear deformation equation
# Optimality condition 2003932662955200.0
# cost at iteration 944 :  70120.97713310471
# solving linear deformation equation
# Optimality condition 1998097764802553.0
# cost at iteration 945 :  70139.86403792532
# solving linear deformation equation
# Optimality condition 1992259364459441.2
# cost at iteration 946 :  70158.65177543456
# solving linear deformation equation
# Optimality condition 1986417507877149.5
# cost at iteration 947 :  70177.34037991925
# solving linear deformation equation
# Optimality condition 1980572240747141.5
# cost at iteration 948 :  70195.92988519254
# solving linear deformation equation
# Optimality condition 1974723608499992.0
# cost at iteration 949 :  70214.42032453344
# solving linear deformation equation
# Optimality condition 1968871656305747.0
# cost at iteration 950 :  70232.81173071226
# solving linear deformation equation
# Optimality condition 1963016429073132.2
# cost at iteration 951 :  70251.10413594767
# solving linear deformation equation
# Optimality condition 1957157971449469.8
# cost at iteration 952 :  70269.29757190245
# solving linear deformation equation
# Optimality condition 1951296327820562.0
# cost at iteration 953 :  70287.39206967992
# solving linear deformation equation
# Optimality condition 1945431542310191.0
# cost at iteration 954 :  70305.38765979168
# solving linear deformation equation
# Optimality condition 1939563658779983.0
# cost at iteration 955 :  70323.28437214752
# solving linear deformation equation
# Optimality condition 1933692720829247.5
# cost at iteration 956 :  70341.08223604751
# solving linear deformation equation
# Optimality condition 1927818771794780.5
# cost at iteration 957 :  70358.78128016346
# solving linear deformation equation
# Optimality condition 1921941854750615.5
# cost at iteration 958 :  70376.38153251966
# solving linear deformation equation
# Optimality condition 1916062012507908.8
# cost at iteration 959 :  70393.88302048134
# solving linear deformation equation
# Optimality condition 1910179287614766.2
# cost at iteration 960 :  70411.28577073275
# solving linear deformation equation
# Optimality condition 1904293722356190.0
# cost at iteration 961 :  70428.58980927488
# solving linear deformation equation
# Optimality condition 1898405358753840.5
# cost at iteration 962 :  70445.79516138832
# solving linear deformation equation
# Optimality condition 1892514238566143.0
# cost at iteration 963 :  70462.90185164109
# solving linear deformation equation
# Optimality condition 1886620403287905.5
# cost at iteration 964 :  70479.90990384393
# solving linear deformation equation
# Optimality condition 1880723894150810.8
# cost at iteration 965 :  70496.81934107096
# solving linear deformation equation
# Optimality condition 1874824752122613.2
# cost at iteration 966 :  70513.63018559295
# solving linear deformation equation
# Optimality condition 1868923017907932.0
# cost at iteration 967 :  70530.34245891268
# solving linear deformation equation
# Optimality condition 1863018731947672.8
# cost at iteration 968 :  70546.95618170589
# solving linear deformation equation
# Optimality condition 1857111934419404.0
# cost at iteration 969 :  70563.47137382803
# solving linear deformation equation
# Optimality condition 1851202665237204.5
# cost at iteration 970 :  70579.88805428297
# solving linear deformation equation
# Optimality condition 1845290964051873.0
# cost at iteration 971 :  70596.20624121258
# solving linear deformation equation
# Optimality condition 1839376870251086.2
# cost at iteration 972 :  70612.42595188126
# solving linear deformation equation
# Optimality condition 1833460422959209.8
# cost at iteration 973 :  70628.5472026357
# solving linear deformation equation
# Optimality condition 1827541661037796.5
# cost at iteration 974 :  70644.57000891303
# solving linear deformation equation
# Optimality condition 1821620623085653.5
# cost at iteration 975 :  70660.49438520869
# solving linear deformation equation
# Optimality condition 1815697347439078.5
# cost at iteration 976 :  70676.32034506381
# solving linear deformation equation
# Optimality condition 1809771872171883.0
# cost at iteration 977 :  70692.04790102766
# solving linear deformation equation
# Optimality condition 1803844235095887.8
# cost at iteration 978 :  70707.67706465982
# solving linear deformation equation
# Optimality condition 1797914473760913.8
# cost at iteration 979 :  70723.20784648196
# solving linear deformation equation
# Optimality condition 1791982625455751.0
# cost at iteration 980 :  70738.64025601147
# solving linear deformation equation
# Optimality condition 1786048727207626.5
# cost at iteration 981 :  70753.97430167181
# solving linear deformation equation
# Optimality condition 1780112815783044.5
# cost at iteration 982 :  70769.20999080875
# solving linear deformation equation
# Optimality condition 1774174927688216.2
# cost at iteration 983 :  70784.34732967262
# solving linear deformation equation
# Optimality condition 1768235099169541.0
# cost at iteration 984 :  70799.38632339562
# solving linear deformation equation
# Optimality condition 1762293366213617.5
# cost at iteration 985 :  70814.32697594028
# solving linear deformation equation
# Optimality condition 1756349764548215.2
# cost at iteration 986 :  70829.16929010989
# solving linear deformation equation
# Optimality condition 1750404329642757.5
# cost at iteration 987 :  70843.9132675243
# solving linear deformation equation
# Optimality condition 1744457096708597.0
# cost at iteration 988 :  70858.55890857264
# solving linear deformation equation
# Optimality condition 1738508100699875.0
# cost at iteration 989 :  70873.10621241316
# solving linear deformation equation
# Optimality condition 1732557376314102.2
# cost at iteration 990 :  70887.55517694076
# solving linear deformation equation
# Optimality condition 1726604957992838.0
# cost at iteration 991 :  70901.90579876624
# solving linear deformation equation
# Optimality condition 1720650879922214.0
# cost at iteration 992 :  70916.15807317683
# solving linear deformation equation
# Optimality condition 1714695176034190.0
# cost at iteration 993 :  70930.31199414819
# solving linear deformation equation
# Optimality condition 1708737880006618.5
# cost at iteration 994 :  70944.3675542653
# solving linear deformation equation
# Optimality condition 1702779025264878.5
# cost at iteration 995 :  70958.3247447564
# solving linear deformation equation
# Optimality condition 1696818644982060.8
# cost at iteration 996 :  70972.18355541764
# solving linear deformation equation
# Optimality condition 1690856772080595.5
# cost at iteration 997 :  70985.94397463207
# solving linear deformation equation
# Optimality condition 1684893439232274.8
# cost at iteration 998 :  70999.60598928003
# solving linear deformation equation
# Optimality condition 1678928678860373.8
# cost at iteration 999 :  71013.16958479198
# solving linear deformation equation
# Optimality condition 1672962523139889.0
# Norm of gset 0.42990752363742873
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112766bb0>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112766770>: Meshpoint 1 not in mesh!
# Error processing element <ngsolve.comp.Ngs_Element object at 0x112766ef0>: Meshpoint 1 not in mesh!
# Mesh quality metrics (min, max, mean, median): 1.001634, 7.270655, 1.463572, 1.138634
# Warning: 67 elements with poor quality (>2)
